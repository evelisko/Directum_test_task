# %% [markdown]
# ### 1. Поиск объектов
#
# На изображении страницы необходимо найти местоположение логотипов и подписей. Для их поиска можно использовать как классические (алгоритмические) подходы computervision, так и подходы с использованием нейронных сетей.
#
# На вход подается файл-изображение в формате **\*.tif**. Адрес API и названия параметров для входных данных придумайте самостоятельно.
#
# > В этом ноудбуке обучается модель для поиска `логотипов`.

# %%
import os
import random
import cv2
from tqdm import tqdm
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
from PIL import Image
from pathlib import Path
import tensorflow as tf
import random
import pickle

random.seed(1)
# Out:
# 2022-05-19 21:23:46.180438: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
# !pip install opencv-python

# %%
gpu_device = tf.config.experimental.list_physical_devices('GPU')
if gpu_device:
    tf.config.experimental.set_memory_growth(gpu_device[0], True)
# Out:
# 2022-05-19 21:23:48.804382: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-05-19 21:23:48.842473: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 21:23:48.842789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.62GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-05-19 21:23:48.842902: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-05-19 21:23:48.950213: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-05-19 21:23:48.950849: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2022-05-19 21:23:49.021031: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2022-05-19 21:23:49.043279: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2022-05-19 21:23:49.060708: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2022-05-19 21:23:49.082368: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2022-05-19 21:23:49.096204: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-05-19 21:23:49.096509: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 21:23:49.097778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 21:23:49.098960: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0

# %%
DATA_ROOT = '../pages/'

class_names = {'Void':0,'DLSignature':1,'DLLogo':2}

IM_SIZE = (600,800) # Все изображения будут приведены этому размеру
 
# Будем подавать изображение в нейронную сеть по частям. 
win_size = 224 #- это размер квадратного окна прохода.
step_x = 100 # шаг перемещения по X
step_y = 100 # шаг перемещения по Y

# Минимальный размер объекта на изображении. 
# Используется удаления лишних bounding box -ов. которые точно не являются логотипами.
min_object_size = 20

# %%
images_path = Path(DATA_ROOT+'source/')
annotation_path = Path(DATA_ROOT+'truth/')

# %%
def filelist(root, file_type):
    """Функция возвращает полностью квалифицированный список файлов в директории"""
    return [os.path.join(directory_path, f) for directory_path, directory_name, 
            files in os.walk(root) for f in files if f.endswith(file_type)]

# %%
def generate_df(path):
    anno_list = []
    annotations = filelist(path, '.xml')
    ns = {'doc': "http://lamp.cfar.umd.edu/GEDI"}

    for anno_path in annotations:
        anno = {}
        root = ET.parse(anno_path).getroot()

        document  = root.find('doc:DL_DOCUMENT',ns)

        doc_attrib = document.attrib

        anno['doc_name'] = Path(str(images_path) + '/'+ doc_attrib['src'])
        anno['pages'] = doc_attrib['NrOfPages']
        #=================================================================#
        page = document.find('doc:DL_PAGE',ns)
        page_attrib = page.attrib
        anno['page_id'] = page_attrib['pageID']
        anno['width'] = int(page_attrib['width'])
        anno['height'] = int(page_attrib['height'])
        #=================================================================#

        zone = page.find('doc:DL_ZONE',ns)

        if zone is not None:
            zone_attrib = zone.attrib

            anno['zone_type'] = zone_attrib['gedi_type']
            anno['zone_col'] = int(zone_attrib['col'])
            anno['zone_row'] = int(zone_attrib['row']) 
            anno['zone_width'] = int(zone_attrib['width'])
            anno['zone_height'] = int(zone_attrib['height'])
 
        anno_list.append(anno)
    return pd.DataFrame(anno_list)

# %%
df = generate_df(annotation_path)
df.head(3)
# Out:
#                                doc_name pages page_id  width  height  \
# 0        ../pages/source/mcm24f00_2.tif     1       1   2592    3300
# 1        ../pages/source/nsr05f00_2.tif     1       1   2592    3300
# 2  ../pages/source/adh36e00-page2_2.tif     1       1   2560    3246
#
#      zone_type  zone_col  zone_row  zone_width  zone_height
# 0          NaN       NaN       NaN         NaN          NaN
# 1          NaN       NaN       NaN         NaN          NaN
# 2  DLSignature    1232.0    2399.0       896.0        431.0

# %%
# Заполним пропуски. 
df.loc[(df['zone_type'].isnull()),'zone_type'] = 'Void'

# Приведем все классы к цыфровому виду.
df['zone_type'] = df['zone_type'].apply(lambda x: class_names[x])

# %% [markdown]
# Функции для обработки изображений и извлечения bounding-box

# %%
def sigmoid(x):
    return 1 / (1 + math.exp(-x))

def read_image(path):
    return cv2.cvtColor(cv2.imread(str(path)), cv2.COLOR_BAYER_BG2GRAY)

def create_mask(bb, x, class_index):
    """Создаем маску для bounding box'a такого же шейпа как и изображение"""
    rows, cols, _ = x.shape
    y_ind = np.zeros((rows, cols)) # Нужно больше каналов.
    y_cat = np.zeros((rows, cols , len(class_names)-1))
    bb = bb.astype(np.int)

    if class_index > 0:
        y_ind[bb[1]:bb[3]+bb[1],bb[0]: bb[2]+bb[0]] = class_index # У нас два класса. И, для каждого из них нужно сделать маску.
        y_cat[bb[1]:bb[3]+bb[1],bb[0]: bb[2]+bb[0], class_index-1] = 1
    return y_cat, y_ind

def create_bb_array(x,class_index):
    """Генерируем массив bounding box'a из столбца train_df"""
    if class_index == 0:
        res = np.array([-1,-1,-1,-1]) 
    else:
        res = np.array([x[0],x[1],x[2],x[3]])      
    return res

def mask_to_bb(mask):
    """Конвертируем маску Y в bounding box'a, принимая 0 как фоновый ненулевой объект """
    cols, rows = np.nonzero(mask)
    if len(cols)==0:
        bb=[0,-1,-1,-1,-1]
    elif ((np.max(rows)- np.min(rows) < min_object_size) or (np.max(cols)- np.min(cols) < min_object_size)):
        bb=[0,-1,-1,-1,-1]
    else:
        top_row = np.min(rows)
        left_col = np.min(cols)
        bottom_row = np.max(rows)
        right_col = np.max(cols)
        centr_row = (top_row+bottom_row)/2
        centr_col = (left_col+right_col)/2
        bb = [win_size, centr_row, centr_col, bottom_row-top_row, right_col-left_col]
    return np.array(bb, dtype=np.float32)/win_size

def resize_image_bb(img_size,img_new_size, bb):
    width, height =  img_size[0], img_size[1]
    new_width, new_height  = img_new_size[0], img_new_size[1]
    height_scale = new_height/height
    width_scale = new_width/width
    bb[0] *= width_scale 
    bb[1] *= height_scale
    bb[2] *= width_scale
    bb[3] *= height_scale
    return bb

# %% [markdown]
# ## Приведем все изображения к единому размеру. 600x800

# %%
new_image_paths = []
new_mask_paths = []
class_index = []
old_width = []
old_height = []
zone_col = []
zone_row = []
zone_width = []
zone_height = []

image_path_resized = Path(DATA_ROOT+'source_prepare')
Path.mkdir(image_path_resized, exist_ok=True)

for index, row in tqdm(df.iterrows()):
    try:
        im_path = Path(row['doc_name'])
        img = cv2.imread(str(im_path))

        img_height = img.shape[0]
        img_width = img.shape[1]

        im_resized = cv2.resize(img, IM_SIZE)
        new_image_path = str(image_path_resized/im_path.parts[-1])
        cv2.imwrite(new_image_path, im_resized)
#=============================================================
        curren_class = row['zone_type']
        bb = create_bb_array(row.values[6:], curren_class)
        bb_resized = resize_image_bb((img_width,img_height),IM_SIZE,bb)
#=============================================================
        col,row, width, height = bb_resized
      
        new_image_paths.append(new_image_path)
        old_height.append(img_height)
        old_width.append(img_width)
        class_index.append(curren_class)
        zone_col.append(col)
        zone_row.append(row)
        zone_width.append(width)
        zone_height.append(height)
        
    except Exception as ex:
        print(index, ex)
    
df_resize = pd.DataFrame({'doc_name':new_image_paths,
                          'old_width': old_width, 'old_height': old_height,
                          'zone_type': class_index, 
                          'zone_col': zone_col, 'zone_row':zone_row, 
                          'zone_width':zone_width, 'zone_height':zone_height})
# Out:
# 1000it [00:53, 18.62it/s]

# %%
df_resize.head()
# Out:
#                                        doc_name  old_width  old_height  \
# 0        ../pages/source_prepare/mcm24f00_2.tif       1200        1575
# 1        ../pages/source_prepare/nsr05f00_2.tif       1200        1575
# 2  ../pages/source_prepare/adh36e00-page2_2.tif       2560        3246
# 3          ../pages/source_prepare/jon00a00.tif       2504        3111
# 4          ../pages/source_prepare/byd23a00.tif       1728        2292
#
#    zone_type    zone_col    zone_row  zone_width  zone_height
# 0          0    0.000000    0.000000    0.000000     0.000000
# 1          0    0.000000    0.000000    0.000000     0.000000
# 2          1  288.750000  591.250770  210.000000   106.223044
# 3          1  329.233227  637.222758  160.063898    78.174221
# 4          1  290.625000  353.926702  104.861111    47.120419

# %% [markdown]
# Выделим из сего набора данных только изображения содержащие логотипы.

# %%
df_logo = df_resize.loc[(df_resize['zone_type']==class_names['DLLogo'])]
df_logo.head(3)
# Out:
#                                          doc_name  old_width  old_height  \
# 13         ../pages/source_prepare/obh31f00_3.tif       1200        1575
# 20  ../pages/source_prepare/rkc33a00-page02_1.tif       2400        3150
# 24  ../pages/source_prepare/cxk72e00-page03_1.tif       2560        3168
#
#     zone_type   zone_col    zone_row  zone_width  zone_height
# 13          2  106.50000   58.412698      66.000    39.111111
# 20          2   45.75000  106.920635      57.750    58.666667
# 24          2  263.90625   30.555556      73.125    45.959596

# %% [markdown]
# Исходное изображение имеет очень большой размер. т.о. оно не помещается в нейронную сеть. Так что оно помещается в нейронную сеть целиком. Для того чтобы обойти это ограничение разрежем изображение на квадраты размером `win_size` (224) c небольшим взаимным перекрытием. И в таком виде будем подавать модель в сеть.

# %% [markdown]
# Определим координаты ограничивающий прямоугольников.

# %%
steps_x = math.ceil(IM_SIZE[0]/step_x)
steps_y = math.ceil(IM_SIZE[1]/step_y)

# запомним позицию каждого квадрата.
step_y, step_x
win_coords = [ ]
for i in range(steps_y):
    for j in range(steps_x):
        pos_x = step_x*j
        pos_y = step_y*i
        if pos_x+win_size> IM_SIZE[0]:
            pos_x = IM_SIZE[0]-win_size
        if pos_y+win_size> IM_SIZE[1]:
            pos_y = IM_SIZE[1]-win_size   
        win_coords.append([pos_y, pos_x, win_size, win_size])

# %%
# Процедура для разбиения изображения на квадраты
def split_image(img, bbx=None, class_index=1):
    is_not_bbx=False
    if not bbx:
        is_not_bbx=True
        bbx = np.array([0,-1,-1,-1,-1], dtype='float')
    _, mask = create_mask(bbx, img, class_index)
    
# разделем изображение на составные части и возращем кусочки small_imgs and small_bbx
    img_combined = np.concatenate([img, mask[..., None]], axis=2)
    X_batch=[]
    y_batch=[]
    for coord in win_coords:
        combined = img_combined[coord[0]:(coord[0]+coord[2]), coord[1]:(coord[1]+coord[3])]
        X_batch.append(combined[...,:3])
        bb = mask_to_bb(combined[...,3])
        y_batch.append(bb)

    X_batch = np.array(X_batch, dtype='float') /255.0
    y_batch = np.array(y_batch, dtype='float')

    if is_not_bbx:
        return X_batch
    else:    
        return X_batch, y_batch

# %%
def show_result(sample_imgs, scores, sample_bbx):
    fig = plt.figure(figsize=(15, 20))
    for j in range(len(sample_imgs)):
        ax = fig.add_subplot(steps_y, steps_x, j+1)
        ax.imshow(sample_imgs[j])
        bb = sample_bbx[j]
        # print(bb)
        wr = bb[2]*win_size
        hc = bb[3]*win_size
        tr = bb[0]*win_size - wr/2
        tc = bb[1]*win_size - hc/2
        rect = plt.Rectangle((tr, tc), wr, hc,fill=False, color='red')
        ax.add_patch(rect)
        ax.title.set_text(f'{scores[j]:.2f}') 
        # print(sigmoid(bb[0]))
        plt.xticks([]), plt.yticks([])
    plt.show()

# %% [markdown]
# ### Генератор.
#  Через него будем подавать изображения в нейронку. Т.к. подаем изображение почастям, то получается так, что буквально 2-3  участка изображения будут содержать логотип, а остальные будут дудут пустыми. Выборка получается несбалансированной. Поэтому применим лайвхак. Будем выбирать только изображения содержащие логотипы и добавлять к ним 3 рандомно выбранные иизображения без объектов.

# %%
from albumentations import ShiftScaleRotate

# %%
# !pip install albumentations

# %%
def strong_aug(p=1.0):
    return ShiftScaleRotate(shift_limit=0.3, 
                                     scale_limit=0.3,
                                     rotate_limit=3,
                                     p=p, 
                                     border_mode=cv2.BORDER_CONSTANT)

# %%
def keras_generator(gen_df, batch_size = 1, is_test=False,is_augmentation=False):
    c = 0
    ind = np.arange(0,len(gen_df))
    random.shuffle(ind)
    augmentation = strong_aug(p=1.0)

    while True:
        X_batch = []
        y_batch = []

        for i in range(c,c + batch_size): # выполняется до тех пор пока не заполится массив.
          row = gen_df.values[ind[i]] # выдает случайный номер картинки. 
          img_name = row[0]

          class_index = row[3]
          bb = row[4:]
          img = cv2.imread(str(img_name))
          img  = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

          # создаем маску из bb?,steps_y
          _, mask = create_mask(bb, img, class_index)
          combined = np.concatenate([img, mask[..., None]], axis=2)
          
          if is_test: # Выведем название картинки.
              print(img_name)
              for coord in win_coords:
                combined_chank = combined[coord[0]:(coord[0]+coord[2]), coord[1]:(coord[1]+coord[3])]
                bb = mask_to_bb(combined_chank[...,3])
                X_batch.append(combined_chank[...,:3])
                y_batch.append(bb)
          else:
          #   Будем брать произвольные квадраты, в которых наших изображений нет. 
              max_void_tyles = 3

              while max_void_tyles > 0:
                  i = random.randint(0, len(win_coords)-1)
                  combined_chank = combined[win_coords[i][0]:(win_coords[i][0]+win_coords[i][2]), win_coords[i][1]:(win_coords[i][1]+win_coords[i][3])]
                  bb = mask_to_bb(combined_chank[...,3])
                  if bb[0]== 0:
                    X_batch.append(combined_chank[...,:3])
                    y_batch.append(bb)
                    max_void_tyles-=1
                    
          # Выбираем только box-ы в которых изображение присутствует.
              for coord in win_coords:
                  combined_chank = combined[coord[0]:(coord[0]+coord[2]), coord[1]:(coord[1]+coord[3])]
                  if is_augmentation==True:
                    data = {'image': combined_chank}
                    augmented = augmentation(**data)
                    combined_chank = augmented["image"]
                  bb = mask_to_bb(combined_chank[...,3])
                  if bb[0]==1:
                    X_batch.append(combined_chank[...,:3])
                    y_batch.append(bb)

        X_batch = np.array(X_batch, dtype='float') /255.0
        y_batch = np.array(y_batch, dtype='float')
        
        c += batch_size
        if(c + batch_size >= len(ind)):
            c = 0
            random.shuffle(ind)

        yield X_batch, (y_batch[:,0], y_batch[:,1:])

# %%
for X_test, y_test in keras_generator(df_logo,batch_size=1,is_augmentation=True):
  break

show_result(X_test, y_test[0],y_test[1])

# %%
test_count = math.floor(len(df_logo)*0.2)

train_logo_df = df_logo.iloc[:-test_count]
test_logo_df =  df_logo.iloc[-test_count:]

# %% [markdown]
# ## Настройка параметров модели.

# %%
# from keras.applications.mobilenet import MobileNet, preprocess_input
# from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
import matplotlib.patches as patches
# from keras.applications.vgg19 import VGG19
# from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout, Dense
# from keras.models import Model
# from tensorflow.keras.models import Sequential
# from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten,Dropout, Input,GlobalAveragePooling2D, BatchNormalization

# %%
WEIGHT_DECAY = 0.001

wd = tf.keras.regularizers.l2(WEIGHT_DECAY)

args = {'padding':'same', 'activation': 'relu','kernel_regularizer':wd}

# %%
base_model = ResNet50(input_shape=(win_size, win_size, 3), include_top=False, pooling='avg')

output = base_model.output

x = Dropout(0.3)(output)
out1 = Dense(1, activation='sigmoid', name='score')(x) # Этим выводам нужно присвоить названия.
out2 = Dense(4, name='bbx')(x)

model_logo = Model(inputs=base_model.input, outputs=[out1, out2])   
# model_custom = Model()
# Out:
# 2022-05-19 21:24:48.284640: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-19 21:24:48.285517: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 21:24:48.286301: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1050 Ti computeCapability: 6.1
# coreClock: 1.62GHz coreCount: 6 deviceMemorySize: 3.95GiB deviceMemoryBandwidth: 104.43GiB/s
# 2022-05-19 21:24:48.286534: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 21:24:48.287540: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 21:24:48.288181: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2022-05-19 21:24:48.288323: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-05-19 21:24:49.304758: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-05-19 21:24:49.304797: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2022-05-19 21:24:49.304808: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2022-05-19 21:24:49.305089: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 21:24:49.305618: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 21:24:49.306291: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 21:24:49.306929: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 3370 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1)

# %%
def loss(gt, pred):
    intersections = 0
    unions = 0
    diff_width = np.minimum(gt[:,0] + gt[:,2], pred[:,0] + pred[:,2]) - np.maximum(gt[:,0], pred[:,2])
    diff_height = np.minimum(gt[:,1] + gt[:,3], pred[:,1] + pred[:,3]) - np.maximum(gt[:,1], pred[:,3])
    intersection = diff_width * diff_height
    
    # Compute union
    area_gt = gt[:,2] * gt[:,3]
    area_pred = pred[:,2] * pred[:,3]
    union = area_gt + area_pred - intersection

    # Compute intersection and union over multiple boxes
    for j, _ in enumerate(union):
        if union[j] > 0 and intersection[j] > 0 and union[j] >= intersection[j]:
            intersections += intersection[j]
            unions += union[j]

    # Compute IOU. Use 1e-8 to prevent division by zero
    iou = np.round(intersections / (unions + 1e-8), 4)
    iou = iou.astype(np.float32)
    return iou

def IoU(y_true, y_pred):
    iou = tf.py_function(loss, [y_true, y_pred], tf.float32)
    return iou

# %%
model_logo.compile(optimizer='Adam', 
              loss={'score':'binary_crossentropy', 'bbx':'mse'},
              metrics={'score': 'accuracy', 'bbx':IoU},
              loss_weights={'score': 1.0, 'bbx':10.0})

# %%
checkpoint_best_IoU = tf.keras.callbacks.ModelCheckpoint('checkpoints/model_logo_15_bestIoU.h5',
                                                  monitor='val_bbx_IoU',
                                                  mode='max',
                                                  save_best_only=True,
                                                  save_weights_only=False,
                                                  save_freq='epoch',
                                                  verbose=1
                                                 )
checkpoint_best_Loss = tf.keras.callbacks.ModelCheckpoint('checkpoints/model_logo_bestLoss.h5',
                                                  monitor='val_loss',
                                                  mode='auto',
                                                  save_best_only=True,
                                                  save_weights_only=False,
                                                  save_freq='epoch',
                                                  verbose=1
                                                 )

# %% [markdown]
# ## Тренировка модели.

# %%
train_generator = keras_generator(train_logo_df,batch_size=1,is_augmentation=True)
val_generator = keras_generator(test_logo_df,batch_size=1)

steps_per_epoch_training = len(train_logo_df)
steps_val = len(test_logo_df)
steps_val, steps_per_epoch_training
# Out:
# (13, 52)

# %%
# for X_test, y_test in keras_generator(train_logo_df,batch_size=1,is_augmentation=True):
#   break

# show_result(X_test, y_test[0],y_test[1])

# %%
NUM_EPOCHS = 100

history = model_logo.fit(train_generator,
                       steps_per_epoch=steps_per_epoch_training,
                       epochs=NUM_EPOCHS,
                       validation_data=val_generator,
                       validation_steps=steps_val, 
                       shuffle=True,
                       callbacks = [checkpoint_best_IoU,checkpoint_best_Loss],
                       verbose=1,
                       )
# Out:
# 2022-05-19 21:24:53.561272: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-05-19 21:24:53.578207: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2799925000 Hz
# Epoch 1/100
# 2022-05-19 21:24:59.197065: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-05-19 21:24:59.708227: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8300
# 2022-05-19 21:25:00.622451: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-05-19 21:25:00.622789: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2022-05-19 21:25:01.179775: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-05-19 21:25:01.196291: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.29GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-05-19 21:25:01.326248: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-05-19 21:25:01.332793: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.29GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-05-19 21:25:01.432463: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-05-19 21:25:01.445701: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
#  1/52 [..............................] - ETA: 7:11 - loss: 8.8540 - score_loss: 1.0811 - bbx_loss: 0.7773 - score_accuracy: 0.4000 - bbx_IoU: 0.1993
# 2022-05-19 21:25:02.502363: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-05-19 21:25:02.520302: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.31GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-05-19 21:25:02.544601: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-05-19 21:25:02.553371: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.31GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 52/52 [==============================] - 28s 387ms/step - loss: 6.9254 - score_loss: 0.4607 - bbx_loss: 0.6465 - score_accuracy: 0.8272 - bbx_IoU: 0.1195 - val_loss: 10020.1650 - val_score_loss: 6.5150 - val_bbx_loss: 1001.3651 - val_score_accuracy: 0.5132 - val_bbx_IoU: 0.0000e+00
#
# Epoch 00001: val_bbx_IoU improved from -inf to 0.00000, saving model to checkpoints/model_logo_15_bestIoU.h5
# /home/sergey/anaconda3/envs/imageai_env/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 00001: val_loss improved from inf to 10020.16504, saving model to checkpoints/model_logo_bestLoss.h5
# Epoch 2/100
# 52/52 [==============================] - 18s 340ms/step - loss: 1.6654 - score_loss: 0.3494 - bbx_loss: 0.1316 - score_accuracy: 0.8732 - bbx_IoU: 0.1176 - val_loss: 4.7949 - val_score_loss: 1.8035 - val_bbx_loss: 0.2991 - val_score_accuracy: 0.5270 - val_bbx_IoU: 0.0000e+00
#
# Epoch 00002: val_bbx_IoU did not improve from 0.00000
#
# Epoch 00002: val_loss improved from 10020.16504 to 4.79490, saving model to checkpoints/model_logo_bestLoss.h5
# Epoch 3/100
# 52/52 [==============================] - 17s 327ms/step - loss: 0.9692 - score_loss: 0.2476 - bbx_loss: 0.0722 - score_accuracy: 0.9200 - bbx_IoU: 0.1769 - val_loss: 1.5599 - val_score_loss: 0.6996 - val_bbx_loss: 0.0860 - val_score_accuracy: 0.4507 - val_bbx_IoU: 0.0000e+00
#
# Epoch 00003: val_bbx_IoU did not improve from 0.00000
#
# Epoch 00003: val_loss improved from 4.79490 to 1.55993, saving model to checkpoints/model_logo_bestLoss.h5
# Epoch 4/100
# 52/52 [==============================] - 15s 299ms/step - loss: 0.6759 - score_loss: 0.1514 - bbx_loss: 0.0525 - score_accuracy: 0.9519 - bbx_IoU: 0.1692 - val_loss: 1.5388 - val_score_loss: 0.6928 - val_bbx_loss: 0.0846 - val_score_accuracy: 0.5132 - val_bbx_IoU: 0.0000e+00
#
# Epoch 00004: val_bbx_IoU did not improve from 0.00000
#
# Epoch 00004: val_loss improved from 1.55993 to 1.53882, saving model to checkpoints/model_logo_bestLoss.h5
# Epoch 5/100
# 52/52 [==============================] - 15s 298ms/step - loss: 0.5190 - score_loss: 0.1178 - bbx_loss: 0.0401 - score_accuracy: 0.9625 - bbx_IoU: 0.1802 - val_loss: 1.2015 - val_score_loss: 0.6888 - val_bbx_loss: 0.0513 - val_score_accuracy: 0.5417 - val_bbx_IoU: 0.2060
#
# Epoch 00005: val_bbx_IoU improved from 0.00000 to 0.20595, saving model to checkpoints/model_logo_15_bestIoU.h5
#
# Epoch 00005: val_loss improved from 1.53882 to 1.20154, saving model to checkpoints/model_logo_bestLoss.h5
# Epoch 6/100
# 52/52 [==============================] - 17s 333ms/step - loss: 0.4474 - score_loss: 0.0950 - bbx_loss: 0.0352 - score_accuracy: 0.9818 - bbx_IoU: 0.1730 - val_loss: 1.4024 - val_score_loss: 0.6910 - val_bbx_loss: 0.0711 - val_score_accuracy: 0.5200 - val_bbx_IoU: 0.3252
#
# Epoch 00006: val_bbx_IoU improved from 0.20595 to 0.32519, saving model to checkpoints/model_logo_15_bestIoU.h5
#
# Epoch 00006: val_loss did not improve from 1.20154
# Epoch 7/100
# 52/52 [==============================] - 15s 293ms/step - loss: 0.3509 - score_loss: 0.0844 - bbx_loss: 0.0267 - score_accuracy: 0.9746 - bbx_IoU: 0.1634 - val_loss: 1.2961 - val_score_loss: 0.6927 - val_bbx_loss: 0.0603 - val_score_accuracy: 0.5479 - val_bbx_IoU: 0.2555
#
# Epoch 00007: val_bbx_IoU did not improve from 0.32519
#
# Epoch 00007: val_loss did not improve from 1.20154
# Epoch 8/100
# 52/52 [==============================] - 15s 299ms/step - loss: 0.2619 - score_loss: 0.0449 - bbx_loss: 0.0217 - score_accuracy: 0.9846 - bbx_IoU: 0.2965 - val_loss: 1.3215 - val_score_loss: 0.6905 - val_bbx_loss: 0.0631 - val_score_accuracy: 0.5263 - val_bbx_IoU: 0.1932
#
# Epoch 00008: val_bbx_IoU did not improve from 0.32519
#
# Epoch 00008: val_loss did not improve from 1.20154
# Epoch 9/100
# 52/52 [==============================] - 16s 310ms/step - loss: 0.2176 - score_loss: 0.0422 - bbx_loss: 0.0175 - score_accuracy: 0.9963 - bbx_IoU: 0.2123 - val_loss: 1.2864 - val_score_loss: 0.6898 - val_bbx_loss: 0.0597 - val_score_accuracy: 0.5417 - val_bbx_IoU: 0.2510
#
# Epoch 00009: val_bbx_IoU did not improve from 0.32519
#
# Epoch 00009: val_loss did not improve from 1.20154
# Epoch 10/100
# 52/52 [==============================] - 15s 298ms/step - loss: 0.2559 - score_loss: 0.0564 - bbx_loss: 0.0200 - score_accuracy: 0.9857 - bbx_IoU: 0.2031 - val_loss: 1.3219 - val_score_loss: 0.6857 - val_bbx_loss: 0.0636 - val_score_accuracy: 0.5395 - val_bbx_IoU: 0.4539
#
# Epoch 00010: val_bbx_IoU improved from 0.32519 to 0.45389, saving model to checkpoints/model_logo_15_bestIoU.h5
#
# Epoch 00010: val_loss did not improve from 1.20154
# Epoch 11/100
# 52/52 [==============================] - 15s 294ms/step - loss: 0.1864 - score_loss: 0.0332 - bbx_loss: 0.0153 - score_accuracy: 1.0000 - bbx_IoU: 0.2224 - val_loss: 1.2854 - val_score_loss: 0.6882 - val_bbx_loss: 0.0597 - val_score_accuracy: 0.5634 - val_bbx_IoU: 0.4543
#
# Epoch 00011: val_bbx_IoU improved from 0.45389 to 0.45429, saving model to checkpoints/model_logo_15_bestIoU.h5
#
# Epoch 00011: val_loss did not improve from 1.20154
# Epoch 12/100
# 52/52 [==============================] - 16s 300ms/step - loss: 0.1899 - score_loss: 0.0502 - bbx_loss: 0.0140 - score_accuracy: 0.9890 - bbx_IoU: 0.2548 - val_loss: 1.1861 - val_score_loss: 0.6903 - val_bbx_loss: 0.0496 - val_score_accuracy: 0.5658 - val_bbx_IoU: 0.2968
#
# Epoch 00012: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00012: val_loss improved from 1.20154 to 1.18607, saving model to checkpoints/model_logo_bestLoss.h5
# Epoch 13/100
# 52/52 [==============================] - 16s 304ms/step - loss: 0.1789 - score_loss: 0.0311 - bbx_loss: 0.0148 - score_accuracy: 0.9930 - bbx_IoU: 0.2350 - val_loss: 1.2114 - val_score_loss: 0.7067 - val_bbx_loss: 0.0505 - val_score_accuracy: 0.5571 - val_bbx_IoU: 0.2496
#
# Epoch 00013: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00013: val_loss did not improve from 1.18607
# Epoch 14/100
# 52/52 [==============================] - 16s 310ms/step - loss: 0.1504 - score_loss: 0.0249 - bbx_loss: 0.0125 - score_accuracy: 0.9929 - bbx_IoU: 0.2528 - val_loss: 1.3049 - val_score_loss: 0.7394 - val_bbx_loss: 0.0566 - val_score_accuracy: 0.5065 - val_bbx_IoU: 0.2853
#
# Epoch 00014: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00014: val_loss did not improve from 1.18607
# Epoch 15/100
# 52/52 [==============================] - 16s 309ms/step - loss: 0.1353 - score_loss: 0.0223 - bbx_loss: 0.0113 - score_accuracy: 0.9964 - bbx_IoU: 0.2528 - val_loss: 1.1575 - val_score_loss: 0.8159 - val_bbx_loss: 0.0342 - val_score_accuracy: 0.5352 - val_bbx_IoU: 0.3439
#
# Epoch 00015: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00015: val_loss improved from 1.18607 to 1.15751, saving model to checkpoints/model_logo_bestLoss.h5
# Epoch 16/100
# 52/52 [==============================] - 15s 298ms/step - loss: 0.1388 - score_loss: 0.0243 - bbx_loss: 0.0114 - score_accuracy: 0.9926 - bbx_IoU: 0.2444 - val_loss: 1.4116 - val_score_loss: 0.9877 - val_bbx_loss: 0.0424 - val_score_accuracy: 0.5417 - val_bbx_IoU: 0.2747
#
# Epoch 00016: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00016: val_loss did not improve from 1.15751
# Epoch 17/100
# 52/52 [==============================] - 13s 249ms/step - loss: 0.1286 - score_loss: 0.0199 - bbx_loss: 0.0109 - score_accuracy: 0.9964 - bbx_IoU: 0.2618 - val_loss: 1.3449 - val_score_loss: 0.9494 - val_bbx_loss: 0.0395 - val_score_accuracy: 0.5513 - val_bbx_IoU: 0.2073
#
# Epoch 00017: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00017: val_loss did not improve from 1.15751
# Epoch 18/100
# 52/52 [==============================] - 10s 198ms/step - loss: 0.1139 - score_loss: 0.0234 - bbx_loss: 0.0090 - score_accuracy: 0.9892 - bbx_IoU: 0.2388 - val_loss: 2.5078 - val_score_loss: 2.0690 - val_bbx_loss: 0.0439 - val_score_accuracy: 0.5342 - val_bbx_IoU: 0.3121
#
# Epoch 00018: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00018: val_loss did not improve from 1.15751
# Epoch 19/100
# 52/52 [==============================] - 10s 191ms/step - loss: 0.1289 - score_loss: 0.0370 - bbx_loss: 0.0092 - score_accuracy: 0.9885 - bbx_IoU: 0.2591 - val_loss: 2.2384 - val_score_loss: 1.6473 - val_bbx_loss: 0.0591 - val_score_accuracy: 0.4933 - val_bbx_IoU: 0.2023
#
# Epoch 00019: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00019: val_loss did not improve from 1.15751
# Epoch 20/100
# 52/52 [==============================] - 10s 195ms/step - loss: 0.1692 - score_loss: 0.0465 - bbx_loss: 0.0123 - score_accuracy: 0.9889 - bbx_IoU: 0.2752 - val_loss: 2.4827 - val_score_loss: 1.9976 - val_bbx_loss: 0.0485 - val_score_accuracy: 0.5735 - val_bbx_IoU: 0.3557
#
# Epoch 00020: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00020: val_loss did not improve from 1.15751
# Epoch 21/100
# 52/52 [==============================] - 10s 194ms/step - loss: 0.1029 - score_loss: 0.0127 - bbx_loss: 0.0090 - score_accuracy: 1.0000 - bbx_IoU: 0.2659 - val_loss: 2.8770 - val_score_loss: 2.1041 - val_bbx_loss: 0.0773 - val_score_accuracy: 0.5200 - val_bbx_IoU: 0.0679
#
# Epoch 00021: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00021: val_loss did not improve from 1.15751
# Epoch 22/100
# 52/52 [==============================] - 10s 193ms/step - loss: 0.0842 - score_loss: 0.0119 - bbx_loss: 0.0072 - score_accuracy: 1.0000 - bbx_IoU: 0.3020 - val_loss: 3.1400 - val_score_loss: 2.3940 - val_bbx_loss: 0.0746 - val_score_accuracy: 0.5417 - val_bbx_IoU: 0.0157
#
# Epoch 00022: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00022: val_loss did not improve from 1.15751
# Epoch 23/100
# 52/52 [==============================] - 10s 196ms/step - loss: 0.1120 - score_loss: 0.0261 - bbx_loss: 0.0086 - score_accuracy: 0.9927 - bbx_IoU: 0.2584 - val_loss: 2.1761 - val_score_loss: 1.7948 - val_bbx_loss: 0.0381 - val_score_accuracy: 0.5735 - val_bbx_IoU: 0.2843
#
# Epoch 00023: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00023: val_loss did not improve from 1.15751
# Epoch 24/100
# 52/52 [==============================] - 10s 198ms/step - loss: 0.1268 - score_loss: 0.0215 - bbx_loss: 0.0105 - score_accuracy: 0.9891 - bbx_IoU: 0.2088 - val_loss: 1.5406 - val_score_loss: 1.0432 - val_bbx_loss: 0.0497 - val_score_accuracy: 0.6667 - val_bbx_IoU: 0.1558
#
# Epoch 00024: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00024: val_loss did not improve from 1.15751
# Epoch 25/100
# 52/52 [==============================] - 10s 194ms/step - loss: 0.0844 - score_loss: 0.0120 - bbx_loss: 0.0072 - score_accuracy: 1.0000 - bbx_IoU: 0.2493 - val_loss: 3.0171 - val_score_loss: 2.4763 - val_bbx_loss: 0.0541 - val_score_accuracy: 0.5270 - val_bbx_IoU: 0.1752
#
# Epoch 00025: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00025: val_loss did not improve from 1.15751
# Epoch 26/100
# 52/52 [==============================] - 10s 197ms/step - loss: 0.0657 - score_loss: 0.0078 - bbx_loss: 0.0058 - score_accuracy: 1.0000 - bbx_IoU: 0.2657 - val_loss: 3.3010 - val_score_loss: 2.6311 - val_bbx_loss: 0.0670 - val_score_accuracy: 0.5493 - val_bbx_IoU: 0.1015
#
# Epoch 00026: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00026: val_loss did not improve from 1.15751
# Epoch 27/100
# 52/52 [==============================] - 10s 196ms/step - loss: 0.0624 - score_loss: 0.0050 - bbx_loss: 0.0057 - score_accuracy: 1.0000 - bbx_IoU: 0.3366 - val_loss: 2.1851 - val_score_loss: 1.8010 - val_bbx_loss: 0.0384 - val_score_accuracy: 0.5200 - val_bbx_IoU: 0.1826
#
# Epoch 00027: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00027: val_loss did not improve from 1.15751
# Epoch 28/100
# 52/52 [==============================] - 10s 196ms/step - loss: 0.0610 - score_loss: 0.0070 - bbx_loss: 0.0054 - score_accuracy: 1.0000 - bbx_IoU: 0.3130 - val_loss: 1.3582 - val_score_loss: 1.0377 - val_bbx_loss: 0.0321 - val_score_accuracy: 0.5897 - val_bbx_IoU: 0.1329
#
# Epoch 00028: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00028: val_loss did not improve from 1.15751
# Epoch 29/100
# 52/52 [==============================] - 10s 191ms/step - loss: 0.0567 - score_loss: 0.0072 - bbx_loss: 0.0049 - score_accuracy: 1.0000 - bbx_IoU: 0.2448 - val_loss: 0.7406 - val_score_loss: 0.6330 - val_bbx_loss: 0.0108 - val_score_accuracy: 0.7083 - val_bbx_IoU: 0.1766
#
# Epoch 00029: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00029: val_loss improved from 1.15751 to 0.74055, saving model to checkpoints/model_logo_bestLoss.h5
# Epoch 30/100
# 52/52 [==============================] - 10s 201ms/step - loss: 0.0611 - score_loss: 0.0081 - bbx_loss: 0.0053 - score_accuracy: 0.9965 - bbx_IoU: 0.3340 - val_loss: 3.5231 - val_score_loss: 2.9896 - val_bbx_loss: 0.0533 - val_score_accuracy: 0.5417 - val_bbx_IoU: 0.1960
#
# Epoch 00030: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00030: val_loss did not improve from 0.74055
# Epoch 31/100
# 52/52 [==============================] - 10s 190ms/step - loss: 0.0436 - score_loss: 0.0028 - bbx_loss: 0.0041 - score_accuracy: 1.0000 - bbx_IoU: 0.3402 - val_loss: 2.7497 - val_score_loss: 2.2379 - val_bbx_loss: 0.0512 - val_score_accuracy: 0.5541 - val_bbx_IoU: 0.1512
#
# Epoch 00031: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00031: val_loss did not improve from 0.74055
# Epoch 32/100
# 52/52 [==============================] - 10s 200ms/step - loss: 0.0775 - score_loss: 0.0142 - bbx_loss: 0.0063 - score_accuracy: 0.9929 - bbx_IoU: 0.2533 - val_loss: 2.0861 - val_score_loss: 1.7036 - val_bbx_loss: 0.0383 - val_score_accuracy: 0.5797 - val_bbx_IoU: 0.2380
#
# Epoch 00032: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00032: val_loss did not improve from 0.74055
# Epoch 33/100
# 52/52 [==============================] - 10s 192ms/step - loss: 0.0769 - score_loss: 0.0184 - bbx_loss: 0.0058 - score_accuracy: 0.9924 - bbx_IoU: 0.2640 - val_loss: 2.9720 - val_score_loss: 2.4536 - val_bbx_loss: 0.0518 - val_score_accuracy: 0.4937 - val_bbx_IoU: 0.3235
#
# Epoch 00033: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00033: val_loss did not improve from 0.74055
# Epoch 34/100
# 52/52 [==============================] - 10s 195ms/step - loss: 0.0568 - score_loss: 0.0067 - bbx_loss: 0.0050 - score_accuracy: 1.0000 - bbx_IoU: 0.2970 - val_loss: 1.9336 - val_score_loss: 1.5480 - val_bbx_loss: 0.0386 - val_score_accuracy: 0.5972 - val_bbx_IoU: 0.1622
#
# Epoch 00034: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00034: val_loss did not improve from 0.74055
# Epoch 35/100
# 52/52 [==============================] - 10s 194ms/step - loss: 0.0528 - score_loss: 0.0064 - bbx_loss: 0.0046 - score_accuracy: 1.0000 - bbx_IoU: 0.2937 - val_loss: 3.9981 - val_score_loss: 3.4358 - val_bbx_loss: 0.0562 - val_score_accuracy: 0.5065 - val_bbx_IoU: 0.2107
#
# Epoch 00035: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00035: val_loss did not improve from 0.74055
# Epoch 36/100
# 52/52 [==============================] - 10s 195ms/step - loss: 0.0552 - score_loss: 0.0118 - bbx_loss: 0.0043 - score_accuracy: 0.9963 - bbx_IoU: 0.2808 - val_loss: 1.1521 - val_score_loss: 0.8558 - val_bbx_loss: 0.0296 - val_score_accuracy: 0.6857 - val_bbx_IoU: 0.1717
#
# Epoch 00036: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00036: val_loss did not improve from 0.74055
# Epoch 37/100
# 52/52 [==============================] - 10s 196ms/step - loss: 0.0469 - score_loss: 0.0052 - bbx_loss: 0.0042 - score_accuracy: 1.0000 - bbx_IoU: 0.3168 - val_loss: 2.3940 - val_score_loss: 1.9370 - val_bbx_loss: 0.0457 - val_score_accuracy: 0.5733 - val_bbx_IoU: 0.2897
#
# Epoch 00037: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00037: val_loss did not improve from 0.74055
# Epoch 38/100
# 52/52 [==============================] - 10s 195ms/step - loss: 0.0627 - score_loss: 0.0092 - bbx_loss: 0.0053 - score_accuracy: 0.9963 - bbx_IoU: 0.3032 - val_loss: 2.0240 - val_score_loss: 1.6961 - val_bbx_loss: 0.0328 - val_score_accuracy: 0.6377 - val_bbx_IoU: 0.0978
#
# Epoch 00038: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00038: val_loss did not improve from 0.74055
# Epoch 39/100
# 52/52 [==============================] - 10s 190ms/step - loss: 0.0387 - score_loss: 0.0032 - bbx_loss: 0.0035 - score_accuracy: 1.0000 - bbx_IoU: 0.3173 - val_loss: 3.0092 - val_score_loss: 2.4899 - val_bbx_loss: 0.0519 - val_score_accuracy: 0.5132 - val_bbx_IoU: 0.2546
#
# Epoch 00039: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00039: val_loss did not improve from 0.74055
# Epoch 40/100
# 52/52 [==============================] - 10s 195ms/step - loss: 0.0619 - score_loss: 0.0095 - bbx_loss: 0.0052 - score_accuracy: 1.0000 - bbx_IoU: 0.2862 - val_loss: 0.9078 - val_score_loss: 0.7171 - val_bbx_loss: 0.0191 - val_score_accuracy: 0.7971 - val_bbx_IoU: 0.1200
#
# Epoch 00040: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00040: val_loss did not improve from 0.74055
# Epoch 41/100
# 52/52 [==============================] - 10s 197ms/step - loss: 0.0732 - score_loss: 0.0086 - bbx_loss: 0.0065 - score_accuracy: 0.9964 - bbx_IoU: 0.2398 - val_loss: 4.5474 - val_score_loss: 3.9986 - val_bbx_loss: 0.0549 - val_score_accuracy: 0.5270 - val_bbx_IoU: 0.2709
#
# Epoch 00041: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00041: val_loss did not improve from 0.74055
# Epoch 42/100
# 52/52 [==============================] - 10s 194ms/step - loss: 0.0476 - score_loss: 0.0042 - bbx_loss: 0.0043 - score_accuracy: 1.0000 - bbx_IoU: 0.2736 - val_loss: 4.8464 - val_score_loss: 4.2444 - val_bbx_loss: 0.0602 - val_score_accuracy: 0.5200 - val_bbx_IoU: 0.3258
#
# Epoch 00042: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00042: val_loss did not improve from 0.74055
# Epoch 43/100
# 52/52 [==============================] - 10s 198ms/step - loss: 0.0454 - score_loss: 0.0054 - bbx_loss: 0.0040 - score_accuracy: 0.9964 - bbx_IoU: 0.2852 - val_loss: 4.0467 - val_score_loss: 3.4159 - val_bbx_loss: 0.0631 - val_score_accuracy: 0.5200 - val_bbx_IoU: 0.0918
#
# Epoch 00043: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00043: val_loss did not improve from 0.74055
# Epoch 44/100
# 52/52 [==============================] - 10s 195ms/step - loss: 0.0495 - score_loss: 0.0095 - bbx_loss: 0.0040 - score_accuracy: 1.0000 - bbx_IoU: 0.3103 - val_loss: 4.1272 - val_score_loss: 3.7240 - val_bbx_loss: 0.0403 - val_score_accuracy: 0.5652 - val_bbx_IoU: 0.1134
#
# Epoch 00044: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00044: val_loss did not improve from 0.74055
# Epoch 45/100
# 52/52 [==============================] - 10s 192ms/step - loss: 0.1245 - score_loss: 0.0524 - bbx_loss: 0.0072 - score_accuracy: 0.9850 - bbx_IoU: 0.2481 - val_loss: 2.2872 - val_score_loss: 1.4505 - val_bbx_loss: 0.0837 - val_score_accuracy: 0.5205 - val_bbx_IoU: 0.0946
#
# Epoch 00045: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00045: val_loss did not improve from 0.74055
# Epoch 46/100
# 52/52 [==============================] - 10s 198ms/step - loss: 0.0935 - score_loss: 0.0255 - bbx_loss: 0.0068 - score_accuracy: 0.9928 - bbx_IoU: 0.2816 - val_loss: 2.3895 - val_score_loss: 1.8502 - val_bbx_loss: 0.0539 - val_score_accuracy: 0.5270 - val_bbx_IoU: 0.1995
#
# Epoch 00046: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00046: val_loss did not improve from 0.74055
# Epoch 47/100
# 52/52 [==============================] - 10s 193ms/step - loss: 0.0864 - score_loss: 0.0149 - bbx_loss: 0.0072 - score_accuracy: 0.9962 - bbx_IoU: 0.2194 - val_loss: 1.2355 - val_score_loss: 0.9777 - val_bbx_loss: 0.0258 - val_score_accuracy: 0.6575 - val_bbx_IoU: 0.1293
#
# Epoch 00047: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00047: val_loss did not improve from 0.74055
# Epoch 48/100
# 52/52 [==============================] - 10s 198ms/step - loss: 0.0778 - score_loss: 0.0104 - bbx_loss: 0.0067 - score_accuracy: 1.0000 - bbx_IoU: 0.3027 - val_loss: 1.2749 - val_score_loss: 1.0404 - val_bbx_loss: 0.0234 - val_score_accuracy: 0.6486 - val_bbx_IoU: 0.1647
#
# Epoch 00048: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00048: val_loss did not improve from 0.74055
# Epoch 49/100
# 52/52 [==============================] - 10s 192ms/step - loss: 0.0795 - score_loss: 0.0056 - bbx_loss: 0.0074 - score_accuracy: 1.0000 - bbx_IoU: 0.2790 - val_loss: 2.2632 - val_score_loss: 1.9327 - val_bbx_loss: 0.0330 - val_score_accuracy: 0.5676 - val_bbx_IoU: 0.2612
#
# Epoch 00049: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00049: val_loss did not improve from 0.74055
# Epoch 50/100
# 52/52 [==============================] - 10s 196ms/step - loss: 0.0476 - score_loss: 0.0048 - bbx_loss: 0.0043 - score_accuracy: 1.0000 - bbx_IoU: 0.2945 - val_loss: 1.2465 - val_score_loss: 1.0419 - val_bbx_loss: 0.0205 - val_score_accuracy: 0.7067 - val_bbx_IoU: 0.1532
#
# Epoch 00050: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00050: val_loss did not improve from 0.74055
# Epoch 51/100
# 52/52 [==============================] - 10s 193ms/step - loss: 0.0488 - score_loss: 0.0030 - bbx_loss: 0.0046 - score_accuracy: 1.0000 - bbx_IoU: 0.2638 - val_loss: 2.5632 - val_score_loss: 2.2137 - val_bbx_loss: 0.0350 - val_score_accuracy: 0.6154 - val_bbx_IoU: 0.3324
#
# Epoch 00051: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00051: val_loss did not improve from 0.74055
# Epoch 52/100
# 52/52 [==============================] - 10s 197ms/step - loss: 0.0544 - score_loss: 0.0072 - bbx_loss: 0.0047 - score_accuracy: 0.9964 - bbx_IoU: 0.2908 - val_loss: 0.6357 - val_score_loss: 0.3804 - val_bbx_loss: 0.0255 - val_score_accuracy: 0.8228 - val_bbx_IoU: 0.1417
#
# Epoch 00052: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00052: val_loss improved from 0.74055 to 0.63571, saving model to checkpoints/model_logo_bestLoss.h5
# Epoch 53/100
# 52/52 [==============================] - 10s 196ms/step - loss: 0.0545 - score_loss: 0.0047 - bbx_loss: 0.0050 - score_accuracy: 1.0000 - bbx_IoU: 0.3137 - val_loss: 2.2628 - val_score_loss: 1.8289 - val_bbx_loss: 0.0434 - val_score_accuracy: 0.6164 - val_bbx_IoU: 0.2488
#
# Epoch 00053: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00053: val_loss did not improve from 0.63571
# Epoch 54/100
# 52/52 [==============================] - 10s 195ms/step - loss: 0.0587 - score_loss: 0.0063 - bbx_loss: 0.0052 - score_accuracy: 0.9963 - bbx_IoU: 0.3029 - val_loss: 3.3535 - val_score_loss: 2.7218 - val_bbx_loss: 0.0632 - val_score_accuracy: 0.5479 - val_bbx_IoU: 0.1983
#
# Epoch 00054: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00054: val_loss did not improve from 0.63571
# Epoch 55/100
# 52/52 [==============================] - 10s 198ms/step - loss: 0.0401 - score_loss: 0.0020 - bbx_loss: 0.0038 - score_accuracy: 1.0000 - bbx_IoU: 0.2651 - val_loss: 1.1742 - val_score_loss: 1.0117 - val_bbx_loss: 0.0163 - val_score_accuracy: 0.7324 - val_bbx_IoU: 0.2689
#
# Epoch 00055: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00055: val_loss did not improve from 0.63571
# Epoch 56/100
# 52/52 [==============================] - 10s 195ms/step - loss: 0.0287 - score_loss: 0.0013 - bbx_loss: 0.0027 - score_accuracy: 1.0000 - bbx_IoU: 0.3934 - val_loss: 2.3372 - val_score_loss: 2.1465 - val_bbx_loss: 0.0191 - val_score_accuracy: 0.5063 - val_bbx_IoU: 0.1546
#
# Epoch 00056: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00056: val_loss did not improve from 0.63571
# Epoch 57/100
# 52/52 [==============================] - 10s 196ms/step - loss: 0.0364 - score_loss: 0.0010 - bbx_loss: 0.0035 - score_accuracy: 1.0000 - bbx_IoU: 0.2908 - val_loss: 3.2529 - val_score_loss: 2.8828 - val_bbx_loss: 0.0370 - val_score_accuracy: 0.6029 - val_bbx_IoU: 0.1413
#
# Epoch 00057: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00057: val_loss did not improve from 0.63571
# Epoch 58/100
# 52/52 [==============================] - 13s 244ms/step - loss: 0.0404 - score_loss: 0.0035 - bbx_loss: 0.0037 - score_accuracy: 1.0000 - bbx_IoU: 0.2896 - val_loss: 2.2844 - val_score_loss: 1.9408 - val_bbx_loss: 0.0344 - val_score_accuracy: 0.6056 - val_bbx_IoU: 0.1848
#
# Epoch 00058: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00058: val_loss did not improve from 0.63571
# Epoch 59/100
# 52/52 [==============================] - 16s 307ms/step - loss: 0.0355 - score_loss: 0.0025 - bbx_loss: 0.0033 - score_accuracy: 1.0000 - bbx_IoU: 0.3241 - val_loss: 1.6922 - val_score_loss: 1.4684 - val_bbx_loss: 0.0224 - val_score_accuracy: 0.7808 - val_bbx_IoU: 0.1881
#
# Epoch 00059: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00059: val_loss did not improve from 0.63571
# Epoch 60/100
# 52/52 [==============================] - 15s 293ms/step - loss: 0.0494 - score_loss: 0.0052 - bbx_loss: 0.0044 - score_accuracy: 1.0000 - bbx_IoU: 0.3177 - val_loss: 1.9145 - val_score_loss: 1.7192 - val_bbx_loss: 0.0195 - val_score_accuracy: 0.5455 - val_bbx_IoU: 0.2608
#
# Epoch 00060: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00060: val_loss did not improve from 0.63571
# Epoch 61/100
# 52/52 [==============================] - 14s 274ms/step - loss: 0.0452 - score_loss: 0.0019 - bbx_loss: 0.0043 - score_accuracy: 1.0000 - bbx_IoU: 0.2727 - val_loss: 4.3370 - val_score_loss: 3.8530 - val_bbx_loss: 0.0484 - val_score_accuracy: 0.5270 - val_bbx_IoU: 0.2786
#
# Epoch 00061: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00061: val_loss did not improve from 0.63571
# Epoch 62/100
# 52/52 [==============================] - 14s 277ms/step - loss: 0.0454 - score_loss: 0.0024 - bbx_loss: 0.0043 - score_accuracy: 1.0000 - bbx_IoU: 0.2571 - val_loss: 3.6611 - val_score_loss: 3.1744 - val_bbx_loss: 0.0487 - val_score_accuracy: 0.5405 - val_bbx_IoU: 0.2115
#
# Epoch 00062: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00062: val_loss did not improve from 0.63571
# Epoch 63/100
# 52/52 [==============================] - 14s 278ms/step - loss: 0.0312 - score_loss: 0.0017 - bbx_loss: 0.0029 - score_accuracy: 1.0000 - bbx_IoU: 0.3420 - val_loss: 3.2600 - val_score_loss: 2.8122 - val_bbx_loss: 0.0448 - val_score_accuracy: 0.5263 - val_bbx_IoU: 0.1799
#
# Epoch 00063: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00063: val_loss did not improve from 0.63571
# Epoch 64/100
# 52/52 [==============================] - 14s 274ms/step - loss: 0.0328 - score_loss: 0.0014 - bbx_loss: 0.0031 - score_accuracy: 1.0000 - bbx_IoU: 0.2789 - val_loss: 4.5785 - val_score_loss: 4.0909 - val_bbx_loss: 0.0488 - val_score_accuracy: 0.5735 - val_bbx_IoU: 0.2172
#
# Epoch 00064: val_bbx_IoU did not improve from 0.45429
#
# Epoch 00064: val_loss did not improve from 0.63571
# Epoch 65/100
# 52/52 [==============================] - 14s 263ms/step - loss: 0.0321 - score_loss: 0.0015 - bbx_loss: 0.0031 - score_accuracy: 1.0000 - bbx_IoU: 0.3341 - val_loss: 4.2858 - val_score_loss: 3.8979 - val_bbx_loss: 0.0388 - val_score_accuracy: 0.5417 - val_bbx_IoU: 0.4704
#
# Epoch 00065: val_bbx_IoU improved from 0.45429 to 0.47042, saving model to checkpoints/model_logo_15_bestIoU.h5
#
# Epoch 00065: val_loss did not improve from 0.63571
# Epoch 66/100
# 52/52 [==============================] - 15s 282ms/step - loss: 0.0364 - score_loss: 0.0083 - bbx_loss: 0.0028 - score_accuracy: 0.9964 - bbx_IoU: 0.3376 - val_loss: 0.6767 - val_score_loss: 0.5879 - val_bbx_loss: 0.0089 - val_score_accuracy: 0.8514 - val_bbx_IoU: 0.1853
#
# Epoch 00066: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00066: val_loss did not improve from 0.63571
# Epoch 67/100
# 52/52 [==============================] - 15s 288ms/step - loss: 0.0291 - score_loss: 0.0013 - bbx_loss: 0.0028 - score_accuracy: 1.0000 - bbx_IoU: 0.3465 - val_loss: 0.3968 - val_score_loss: 0.3281 - val_bbx_loss: 0.0069 - val_score_accuracy: 0.8857 - val_bbx_IoU: 0.2067
#
# Epoch 00067: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00067: val_loss improved from 0.63571 to 0.39681, saving model to checkpoints/model_logo_bestLoss.h5
# Epoch 68/100
# 52/52 [==============================] - 14s 270ms/step - loss: 0.0391 - score_loss: 0.0029 - bbx_loss: 0.0036 - score_accuracy: 1.0000 - bbx_IoU: 0.2488 - val_loss: 0.6058 - val_score_loss: 0.5013 - val_bbx_loss: 0.0105 - val_score_accuracy: 0.8000 - val_bbx_IoU: 0.1966
#
# Epoch 00068: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00068: val_loss did not improve from 0.39681
# Epoch 69/100
# 52/52 [==============================] - 14s 277ms/step - loss: 0.0319 - score_loss: 0.0016 - bbx_loss: 0.0030 - score_accuracy: 1.0000 - bbx_IoU: 0.3403 - val_loss: 0.4082 - val_score_loss: 0.3061 - val_bbx_loss: 0.0102 - val_score_accuracy: 0.8987 - val_bbx_IoU: 0.2263
#
# Epoch 00069: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00069: val_loss did not improve from 0.39681
# Epoch 70/100
# 52/52 [==============================] - 14s 280ms/step - loss: 0.0230 - score_loss: 9.0960e-04 - bbx_loss: 0.0022 - score_accuracy: 1.0000 - bbx_IoU: 0.3714 - val_loss: 1.1459 - val_score_loss: 0.9694 - val_bbx_loss: 0.0176 - val_score_accuracy: 0.7568 - val_bbx_IoU: 0.1309
#
# Epoch 00070: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00070: val_loss did not improve from 0.39681
# Epoch 71/100
# 52/52 [==============================] - 14s 279ms/step - loss: 0.0272 - score_loss: 0.0017 - bbx_loss: 0.0026 - score_accuracy: 1.0000 - bbx_IoU: 0.3105 - val_loss: 2.5305 - val_score_loss: 2.1828 - val_bbx_loss: 0.0348 - val_score_accuracy: 0.6143 - val_bbx_IoU: 0.1669
#
# Epoch 00071: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00071: val_loss did not improve from 0.39681
# Epoch 72/100
# 52/52 [==============================] - 15s 282ms/step - loss: 0.0293 - score_loss: 0.0017 - bbx_loss: 0.0028 - score_accuracy: 1.0000 - bbx_IoU: 0.3134 - val_loss: 3.4392 - val_score_loss: 2.9954 - val_bbx_loss: 0.0444 - val_score_accuracy: 0.5325 - val_bbx_IoU: 0.1964
#
# Epoch 00072: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00072: val_loss did not improve from 0.39681
# Epoch 73/100
# 52/52 [==============================] - 14s 275ms/step - loss: 0.1652 - score_loss: 0.0637 - bbx_loss: 0.0101 - score_accuracy: 0.9724 - bbx_IoU: 0.2007 - val_loss: 14.0154 - val_score_loss: 13.3998 - val_bbx_loss: 0.0616 - val_score_accuracy: 0.5000 - val_bbx_IoU: 0.3782
#
# Epoch 00073: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00073: val_loss did not improve from 0.39681
# Epoch 74/100
# 52/52 [==============================] - 14s 280ms/step - loss: 0.2245 - score_loss: 0.0439 - bbx_loss: 0.0181 - score_accuracy: 0.9891 - bbx_IoU: 0.2162 - val_loss: 102.0815 - val_score_loss: 4.6019 - val_bbx_loss: 9.7480 - val_score_accuracy: 0.3571 - val_bbx_IoU: 0.2319
#
# Epoch 00074: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00074: val_loss did not improve from 0.39681
# Epoch 75/100
# 52/52 [==============================] - 14s 276ms/step - loss: 0.1038 - score_loss: 0.0045 - bbx_loss: 0.0099 - score_accuracy: 1.0000 - bbx_IoU: 0.2420 - val_loss: 4.2125 - val_score_loss: 3.7109 - val_bbx_loss: 0.0502 - val_score_accuracy: 0.5652 - val_bbx_IoU: 0.2826
#
# Epoch 00075: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00075: val_loss did not improve from 0.39681
# Epoch 76/100
# 52/52 [==============================] - 14s 277ms/step - loss: 0.1662 - score_loss: 0.0396 - bbx_loss: 0.0127 - score_accuracy: 0.9742 - bbx_IoU: 0.2045 - val_loss: 3.5309 - val_score_loss: 2.4894 - val_bbx_loss: 0.1041 - val_score_accuracy: 0.5132 - val_bbx_IoU: 0.2299
#
# Epoch 00076: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00076: val_loss did not improve from 0.39681
# Epoch 77/100
# 52/52 [==============================] - 14s 272ms/step - loss: 0.1441 - score_loss: 0.0387 - bbx_loss: 0.0105 - score_accuracy: 0.9926 - bbx_IoU: 0.2028 - val_loss: 3.6576 - val_score_loss: 2.5990 - val_bbx_loss: 0.1059 - val_score_accuracy: 0.5200 - val_bbx_IoU: 0.0593
#
# Epoch 00077: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00077: val_loss did not improve from 0.39681
# Epoch 78/100
# 52/52 [==============================] - 14s 277ms/step - loss: 0.0971 - score_loss: 0.0069 - bbx_loss: 0.0090 - score_accuracy: 1.0000 - bbx_IoU: 0.2797 - val_loss: 3.1538 - val_score_loss: 2.5378 - val_bbx_loss: 0.0616 - val_score_accuracy: 0.5493 - val_bbx_IoU: 0.1365
#
# Epoch 00078: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00078: val_loss did not improve from 0.39681
# Epoch 79/100
# 52/52 [==============================] - 14s 272ms/step - loss: 0.0707 - score_loss: 0.0037 - bbx_loss: 0.0067 - score_accuracy: 1.0000 - bbx_IoU: 0.2627 - val_loss: 3.1327 - val_score_loss: 2.5978 - val_bbx_loss: 0.0535 - val_score_accuracy: 0.5270 - val_bbx_IoU: 0.2791
#
# Epoch 00079: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00079: val_loss did not improve from 0.39681
# Epoch 80/100
# 52/52 [==============================] - 14s 280ms/step - loss: 0.1283 - score_loss: 0.0343 - bbx_loss: 0.0094 - score_accuracy: 0.9886 - bbx_IoU: 0.2105 - val_loss: 137.7418 - val_score_loss: 2.7637 - val_bbx_loss: 13.4978 - val_score_accuracy: 0.5195 - val_bbx_IoU: 0.1317
#
# Epoch 00080: val_bbx_IoU did not improve from 0.47042
#
# Epoch 00080: val_loss did not improve from 0.39681
# Epoch 81/100
# 52/52 [==============================] - 14s 275ms/step - loss: 0.1935 - score_loss: 0.0231 - bbx_loss: 0.0170 - score_accuracy: 0.9897 - bbx_IoU: 0.2417 - val_loss: 35.9059 - val_score_loss: 4.2813 - val_bbx_loss: 3.1625 - val_score_accuracy: 0.4583 - val_bbx_IoU: 0.6027
#
# Epoch 00081: val_bbx_IoU improved from 0.47042 to 0.60274, saving model to checkpoints/model_logo_15_bestIoU.h5
#
# Epoch 00081: val_loss did not improve from 0.39681
# Epoch 82/100
# 52/52 [==============================] - 14s 279ms/step - loss: 0.1127 - score_loss: 0.0145 - bbx_loss: 0.0098 - score_accuracy: 0.9962 - bbx_IoU: 0.2214 - val_loss: 7.0043 - val_score_loss: 5.5001 - val_bbx_loss: 0.1504 - val_score_accuracy: 0.4800 - val_bbx_IoU: 0.0369
#
# Epoch 00082: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00082: val_loss did not improve from 0.39681
# Epoch 83/100
# 52/52 [==============================] - 14s 277ms/step - loss: 0.0955 - score_loss: 0.0072 - bbx_loss: 0.0088 - score_accuracy: 0.9963 - bbx_IoU: 0.2339 - val_loss: 3.0142 - val_score_loss: 2.5834 - val_bbx_loss: 0.0431 - val_score_accuracy: 0.5882 - val_bbx_IoU: 0.1628
#
# Epoch 00083: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00083: val_loss did not improve from 0.39681
# Epoch 84/100
# 52/52 [==============================] - 14s 280ms/step - loss: 0.0676 - score_loss: 0.0049 - bbx_loss: 0.0063 - score_accuracy: 1.0000 - bbx_IoU: 0.2211 - val_loss: 3.4154 - val_score_loss: 2.9966 - val_bbx_loss: 0.0419 - val_score_accuracy: 0.5200 - val_bbx_IoU: 0.2205
#
# Epoch 00084: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00084: val_loss did not improve from 0.39681
# Epoch 85/100
# 52/52 [==============================] - 14s 272ms/step - loss: 0.1237 - score_loss: 0.0354 - bbx_loss: 0.0088 - score_accuracy: 0.9854 - bbx_IoU: 0.2658 - val_loss: 4.3542 - val_score_loss: 3.5604 - val_bbx_loss: 0.0794 - val_score_accuracy: 0.5270 - val_bbx_IoU: 0.1049
#
# Epoch 00085: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00085: val_loss did not improve from 0.39681
# Epoch 86/100
# 52/52 [==============================] - 15s 295ms/step - loss: 0.0692 - score_loss: 0.0059 - bbx_loss: 0.0063 - score_accuracy: 1.0000 - bbx_IoU: 0.2282 - val_loss: 4.9285 - val_score_loss: 4.3315 - val_bbx_loss: 0.0597 - val_score_accuracy: 0.5342 - val_bbx_IoU: 0.2549
#
# Epoch 00086: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00086: val_loss did not improve from 0.39681
# Epoch 87/100
# 52/52 [==============================] - 14s 280ms/step - loss: 0.0870 - score_loss: 0.0173 - bbx_loss: 0.0070 - score_accuracy: 0.9963 - bbx_IoU: 0.2629 - val_loss: 5.5608 - val_score_loss: 4.9524 - val_bbx_loss: 0.0608 - val_score_accuracy: 0.5200 - val_bbx_IoU: 0.3909
#
# Epoch 00087: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00087: val_loss did not improve from 0.39681
# Epoch 88/100
# 52/52 [==============================] - 15s 281ms/step - loss: 0.0465 - score_loss: 0.0045 - bbx_loss: 0.0042 - score_accuracy: 1.0000 - bbx_IoU: 0.3167 - val_loss: 3.2686 - val_score_loss: 2.8799 - val_bbx_loss: 0.0389 - val_score_accuracy: 0.5909 - val_bbx_IoU: 0.1262
#
# Epoch 00088: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00088: val_loss did not improve from 0.39681
# Epoch 89/100
# 52/52 [==============================] - 15s 286ms/step - loss: 0.0406 - score_loss: 0.0024 - bbx_loss: 0.0038 - score_accuracy: 1.0000 - bbx_IoU: 0.3258 - val_loss: 1.6804 - val_score_loss: 1.4022 - val_bbx_loss: 0.0278 - val_score_accuracy: 0.7179 - val_bbx_IoU: 0.0560
#
# Epoch 00089: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00089: val_loss did not improve from 0.39681
# Epoch 90/100
# 52/52 [==============================] - 14s 277ms/step - loss: 0.0627 - score_loss: 0.0135 - bbx_loss: 0.0049 - score_accuracy: 0.9924 - bbx_IoU: 0.2390 - val_loss: 4.6086 - val_score_loss: 3.9889 - val_bbx_loss: 0.0620 - val_score_accuracy: 0.5493 - val_bbx_IoU: 0.0744
#
# Epoch 00090: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00090: val_loss did not improve from 0.39681
# Epoch 91/100
# 52/52 [==============================] - 15s 281ms/step - loss: 0.0522 - score_loss: 0.0068 - bbx_loss: 0.0045 - score_accuracy: 0.9964 - bbx_IoU: 0.2924 - val_loss: 3.3666 - val_score_loss: 2.8701 - val_bbx_loss: 0.0497 - val_score_accuracy: 0.5556 - val_bbx_IoU: 0.1530
#
# Epoch 00091: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00091: val_loss did not improve from 0.39681
# Epoch 92/100
# 52/52 [==============================] - 15s 287ms/step - loss: 0.0440 - score_loss: 0.0029 - bbx_loss: 0.0041 - score_accuracy: 1.0000 - bbx_IoU: 0.3205 - val_loss: 4.3302 - val_score_loss: 3.8610 - val_bbx_loss: 0.0469 - val_score_accuracy: 0.5065 - val_bbx_IoU: 0.0666
#
# Epoch 00092: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00092: val_loss did not improve from 0.39681
# Epoch 93/100
# 52/52 [==============================] - 15s 282ms/step - loss: 0.0556 - score_loss: 0.0072 - bbx_loss: 0.0048 - score_accuracy: 1.0000 - bbx_IoU: 0.2876 - val_loss: 1.1968 - val_score_loss: 0.9750 - val_bbx_loss: 0.0222 - val_score_accuracy: 0.7260 - val_bbx_IoU: 0.2314
#
# Epoch 00093: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00093: val_loss did not improve from 0.39681
# Epoch 94/100
# 52/52 [==============================] - 16s 302ms/step - loss: 0.0459 - score_loss: 0.0015 - bbx_loss: 0.0044 - score_accuracy: 1.0000 - bbx_IoU: 0.3125 - val_loss: 1.3697 - val_score_loss: 1.2167 - val_bbx_loss: 0.0153 - val_score_accuracy: 0.7183 - val_bbx_IoU: 0.2227
#
# Epoch 00094: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00094: val_loss did not improve from 0.39681
# Epoch 95/100
# 52/52 [==============================] - 15s 292ms/step - loss: 0.0414 - score_loss: 0.0035 - bbx_loss: 0.0038 - score_accuracy: 1.0000 - bbx_IoU: 0.3097 - val_loss: 1.3563 - val_score_loss: 1.1725 - val_bbx_loss: 0.0184 - val_score_accuracy: 0.7042 - val_bbx_IoU: 0.2363
#
# Epoch 00095: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00095: val_loss did not improve from 0.39681
# Epoch 96/100
# 52/52 [==============================] - 15s 292ms/step - loss: 0.0278 - score_loss: 0.0015 - bbx_loss: 0.0026 - score_accuracy: 1.0000 - bbx_IoU: 0.2975 - val_loss: 1.3108 - val_score_loss: 1.0899 - val_bbx_loss: 0.0221 - val_score_accuracy: 0.7179 - val_bbx_IoU: 0.1903
#
# Epoch 00096: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00096: val_loss did not improve from 0.39681
# Epoch 97/100
# 52/52 [==============================] - 15s 283ms/step - loss: 0.0309 - score_loss: 0.0011 - bbx_loss: 0.0030 - score_accuracy: 1.0000 - bbx_IoU: 0.3032 - val_loss: 1.1749 - val_score_loss: 1.0080 - val_bbx_loss: 0.0167 - val_score_accuracy: 0.6933 - val_bbx_IoU: 0.3030
#
# Epoch 00097: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00097: val_loss did not improve from 0.39681
# Epoch 98/100
# 52/52 [==============================] - 14s 273ms/step - loss: 0.0341 - score_loss: 9.3581e-04 - bbx_loss: 0.0033 - score_accuracy: 1.0000 - bbx_IoU: 0.3411 - val_loss: 1.0312 - val_score_loss: 0.9201 - val_bbx_loss: 0.0111 - val_score_accuracy: 0.7286 - val_bbx_IoU: 0.2631
#
# Epoch 00098: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00098: val_loss did not improve from 0.39681
# Epoch 99/100
# 52/52 [==============================] - 14s 276ms/step - loss: 0.0308 - score_loss: 0.0016 - bbx_loss: 0.0029 - score_accuracy: 1.0000 - bbx_IoU: 0.3184 - val_loss: 4.1963 - val_score_loss: 3.6656 - val_bbx_loss: 0.0531 - val_score_accuracy: 0.5467 - val_bbx_IoU: 0.0913
#
# Epoch 00099: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00099: val_loss did not improve from 0.39681
# Epoch 100/100
# 52/52 [==============================] - 15s 294ms/step - loss: 0.0637 - score_loss: 0.0152 - bbx_loss: 0.0048 - score_accuracy: 0.9888 - bbx_IoU: 0.3064 - val_loss: 8.2707 - val_score_loss: 7.4675 - val_bbx_loss: 0.0803 - val_score_accuracy: 0.5067 - val_bbx_IoU: 0.1730
#
# Epoch 00100: val_bbx_IoU did not improve from 0.60274
#
# Epoch 00100: val_loss did not improve from 0.39681

# %%
model_logo.save(f'checkpoints/model_logo_15_{NUM_EPOCHS}.h5')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'] )
plt.semilogy()#set_yscale('log')
# plt.loglog(basex=10,basey=2)
plt.show()

# %%
model_logo.load_weights('checkpoints/model_logo_bestLoss.h5')

# %%
model_logo.save('../models/model_logo.h5')

# %%
# определим реальную позицию прямоугольников и их координаты на изначальном изображении.
# Объединим все bounding box-ы в один.

def combined_bb(win_coords,scores, bbx, threshold=0.9):
    if np.max(scores)< threshold:
        return [-1,-1,-1,-1]
        
    top_row,left_col,bottom_row,right_col= -1,-1,-1,-1
    counter = 0
    for i, b in enumerate(bbx):
        if (scores[i] >= threshold):
            counter +=1
            box = b * win_size
            box[0] += win_coords[i][1]-box[2]/2  
            box[1] += win_coords[i][0]-box[3]/2
            box[2] += box[0]  
            box[3] += box[1]
            # if(box[1]< IM_SIZE[1]/2):
            #     continue
            if(box[1]> IM_SIZE[1]/2):
                continue
            # print(box)
            if counter==1:
                top_row = box[0] 
                left_col = box[1]
                bottom_row = box[2]
                right_col = box[3]
            else:
                if(np.abs(top_row - box[0]) > win_size/2) or (np.abs(left_col - box[1])> win_size/2):
                    print(np.abs(top_row - box[0]), np.abs(left_col - box[1]) )
                    continue
                top_row = box[0] if box[0] < top_row else top_row
                left_col = box[1] if box[1] < left_col else left_col
                bottom_row = box[2] if box[2] > bottom_row else bottom_row
                right_col = box[3] if box[3] > right_col else right_col
            
            # break
    return [top_row,left_col,bottom_row-top_row,right_col-left_col]

# %%
for X_test, y_test in keras_generator(test_logo_df,batch_size=1,is_test=True):
  break

predict = model_logo.predict(X_test)

show_result(X_test,predict[0][:,0], predict[1])
# Out:
# ../pages/source_prepare/diy01a00-page02_1.tif

# %%
img = cv2.imread('../pages/source_prepare/rqv98d00-page02_1.tif')
img  = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_list = split_image(img)
predict = model_logo.predict(img_list)
show_result(img_list,predict[0][:,0],predict[1])

# Объединим кусочки в одно изображение.
bb = combined_bb(win_coords, predict[0], predict[1], threshold=0.5)
rect = patches.Rectangle((bb[0], bb[1]), bb[2], bb[3], linewidth=1, edgecolor='r', facecolor='none')

fig,ax = plt.subplots(1,1,figsize=(10,10))
ax.imshow(img, 'gray', vmin=0, vmax=1,)
ax.add_patch(rect)
plt.show()

# %% [markdown]
# ### Сохраним модель в формате-pickle.

# %%
model_logo = tf.keras.models.load_model("../models/model_logo.h5", custom_objects={"IoU":IoU})

# %%
# Сохранение модели. 
model_dict = {}

model_dict['graph'] = model_logo.to_json()
model_dict['weights'] = model_logo.get_weights()

# %%
with open('../models/model_logo.pickle', 'wb') as f:
    pickle.dump(model_dict, f, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Проверим качество предсказания после того как модель будет восстановлена.

# %%
with open('../models/model_logo.pickle', 'rb') as f:
   model_dict_restore = pickle.load(f)
   
model = tf.keras.models.model_from_json(model_dict_restore['graph'], custom_objects={"IoU":IoU})
model.set_weights(model_dict_restore['weights'])

# %%
img = cv2.imread('../pages/source_prepare/rqv98d00-page02_1.tif')
img  = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_list = split_image(img)
predict = model.predict(img_list)
show_result(img_list,predict[0][:,0],predict[1])

# Объединим кусочки в одно изображение.
bb = combined_bb(win_coords, predict[0], predict[1], threshold=0.5)
rect = patches.Rectangle((bb[0], bb[1]), bb[2], bb[3], linewidth=1, edgecolor='r', facecolor='none')

fig,ax = plt.subplots(1,1,figsize=(10,10))
ax.imshow(img, 'gray', vmin=0, vmax=1,)
ax.add_patch(rect)
plt.show()
