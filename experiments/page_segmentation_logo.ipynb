# %%
import os
import random
import cv2
from tqdm import tqdm
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
from PIL import Image
from pathlib import Path
import tensorflow as tf
import random

random.seed(1)

# %%
# gpu_device = tf.config.experimental.list_physical_devices('GPU')
# if gpu_device:
#     tf.config.experimental.set_memory_growth(gpu_device[0], True)

# %%
DATA_ROOT = '../pages/'

class_names = {'Void':0,'DLSignature':1,'DLLogo':2}

IM_SIZE = (600,800) # Все изображения будут приведены этому размеру
 
# Будем подавать изображение в нейронную сеть по частям. 
win_size = 224 #- это размер квадратного окна прохода.
step_x = 100 # шаг перемещения по X
step_y = 100 # шаг перемещения по Y

# Минимальный размер объекта на изображении. 
# Используется удаления лишних bounding box -ов. которые точно не являются логотипами.
min_object_size = 20

# %%
images_path = Path(DATA_ROOT+'source/')
annotation_path = Path(DATA_ROOT+'truth/')

# %%
def filelist(root, file_type):
    """Функция возвращает полностью квалифицированный список файлов в директории"""
    return [os.path.join(directory_path, f) for directory_path, directory_name, 
            files in os.walk(root) for f in files if f.endswith(file_type)]

# %%
def generate_df(path):
    anno_list = []
    annotations = filelist(path, '.xml')
    ns = {'doc': "http://lamp.cfar.umd.edu/GEDI"}

    for anno_path in annotations:
        anno = {}
        root = ET.parse(anno_path).getroot()

        document  = root.find('doc:DL_DOCUMENT',ns)

        doc_attrib = document.attrib

        anno['doc_name'] = Path(str(images_path) + '/'+ doc_attrib['src'])
        anno['pages'] = doc_attrib['NrOfPages']
        #=================================================================#
        page = document.find('doc:DL_PAGE',ns)
        page_attrib = page.attrib
        anno['page_id'] = page_attrib['pageID']
        anno['width'] = int(page_attrib['width'])
        anno['height'] = int(page_attrib['height'])
        #=================================================================#

        zone = page.find('doc:DL_ZONE',ns)

        if zone is not None:
            zone_attrib = zone.attrib

            anno['zone_type'] = zone_attrib['gedi_type']
            anno['zone_col'] = int(zone_attrib['col'])
            anno['zone_row'] = int(zone_attrib['row']) 
            anno['zone_width'] = int(zone_attrib['width'])
            anno['zone_height'] = int(zone_attrib['height'])
 
        anno_list.append(anno)
    return pd.DataFrame(anno_list)

# %%
df = generate_df(annotation_path)
df.head(3)
# Out:
#                                doc_name pages page_id  width  height  \
# 0        ../pages/source/mcm24f00_2.tif     1       1   2592    3300
# 1        ../pages/source/nsr05f00_2.tif     1       1   2592    3300
# 2  ../pages/source/adh36e00-page2_2.tif     1       1   2560    3246
#
#      zone_type  zone_col  zone_row  zone_width  zone_height
# 0          NaN       NaN       NaN         NaN          NaN
# 1          NaN       NaN       NaN         NaN          NaN
# 2  DLSignature    1232.0    2399.0       896.0        431.0

# %%
# Заполним пропуски. 
df.loc[(df['zone_type'].isnull()),'zone_type'] = 'Void'

# Приведем все классы к цыфровому виду.
df['zone_type'] = df['zone_type'].apply(lambda x: class_names[x])

# %% [markdown]
# Функции для обработки изображений и извлечения bounding-box

# %%
def sigmoid(x):
    return 1 / (1 + math.exp(-x))

def read_image(path):
    return cv2.cvtColor(cv2.imread(str(path)), cv2.COLOR_BAYER_BG2GRAY)

def create_mask(bb, x, class_index):
    """Создаем маску для bounding box'a такого же шейпа как и изображение"""
    rows, cols, _ = x.shape
    y_ind = np.zeros((rows, cols)) # Нужно больше каналов.
    y_cat = np.zeros((rows, cols , len(class_names)-1))
    bb = bb.astype(np.int)

    if class_index > 0:
        y_ind[bb[1]:bb[3]+bb[1],bb[0]: bb[2]+bb[0]] = class_index # У нас два класса. И, для каждого из них нужно сделать маску.
        y_cat[bb[1]:bb[3]+bb[1],bb[0]: bb[2]+bb[0], class_index-1] = 1
    return y_cat, y_ind

def create_bb_array(x,class_index):
    """Генерируем массив bounding box'a из столбца train_df"""
    if class_index == 0:
        res = np.array([-1,-1,-1,-1]) 
    else:
        res = np.array([x[0],x[1],x[2],x[3]])      
    return res

def mask_to_bb(mask):
    """Конвертируем маску Y в bounding box'a, принимая 0 как фоновый ненулевой объект """
    cols, rows = np.nonzero(mask)
    if len(cols)==0:
        bb=[0,-1,-1,-1,-1]
    elif ((np.max(rows)- np.min(rows) < min_object_size) or (np.max(cols)- np.min(cols) < min_object_size)):
        bb=[0,-1,-1,-1,-1]
    else:
        top_row = np.min(rows)
        left_col = np.min(cols)
        bottom_row = np.max(rows)
        right_col = np.max(cols)
        centr_row = (top_row+bottom_row)/2
        centr_col = (left_col+right_col)/2
        bb = [win_size, centr_row, centr_col, bottom_row-top_row, right_col-left_col]
    return np.array(bb, dtype=np.float32)/win_size

def resize_image_bb(img_size,img_new_size, bb):
    width, height =  img_size[0], img_size[1]
    new_width, new_height  = img_new_size[0], img_new_size[1]
    height_scale = new_height/height
    width_scale = new_width/width
    bb[0] *= width_scale 
    bb[1] *= height_scale
    bb[2] *= width_scale
    bb[3] *= height_scale
    return bb

# %% [markdown]
# ## Приведем все изображения к единому размеру. 600x800

# %%
new_image_paths = []
new_mask_paths = []
class_index = []
old_width = []
old_height = []
zone_col = []
zone_row = []
zone_width = []
zone_height = []

image_path_resized = Path(DATA_ROOT+'source_prepare')
Path.mkdir(image_path_resized, exist_ok=True)

# mask_path_resized = Path(DATA_ROOT+'mask_prepare')
# Path.mkdir(mask_path_resized, exist_ok=True)

for index, row in tqdm(df.iterrows()):
    try:
        im_path = Path(row['doc_name'])
        img = cv2.imread(str(im_path))

        img_height = img.shape[0]
        img_width = img.shape[1]

        im_resized = cv2.resize(img, IM_SIZE)
        new_image_path = str(image_path_resized/im_path.parts[-1])
        cv2.imwrite(new_image_path, im_resized)
#=============================================================
        curren_class = row['zone_type']
        bb = create_bb_array(row.values[6:], curren_class)
        bb_resized = resize_image_bb((img_width,img_height),IM_SIZE,bb)
#=============================================================
        col,row, width, height = bb_resized
      
        new_image_paths.append(new_image_path)
        old_height.append(img_height)
        old_width.append(img_width)
        class_index.append(curren_class)
        zone_col.append(col)
        zone_row.append(row)
        zone_width.append(width)
        zone_height.append(height)
        
    except Exception as ex:
        print(index, ex)
    
df_resize = pd.DataFrame({'doc_name':new_image_paths,
                          'old_width': old_width, 'old_height': old_height,
                          'zone_type': class_index, 
                          'zone_col': zone_col, 'zone_row':zone_row, 
                          'zone_width':zone_width, 'zone_height':zone_height})
# Out:
# 1000it [00:36, 27.65it/s]

# %%
df_resize.head()
# Out:
#                                        doc_name  old_width  old_height  \
# 0        ../pages/source_prepare/mcm24f00_2.tif       1200        1575
# 1        ../pages/source_prepare/nsr05f00_2.tif       1200        1575
# 2  ../pages/source_prepare/adh36e00-page2_2.tif       2560        3246
# 3          ../pages/source_prepare/jon00a00.tif       2504        3111
# 4          ../pages/source_prepare/byd23a00.tif       1728        2292
#
#    zone_type    zone_col    zone_row  zone_width  zone_height
# 0          0    0.000000    0.000000    0.000000     0.000000
# 1          0    0.000000    0.000000    0.000000     0.000000
# 2          1  288.750000  591.250770  210.000000   106.223044
# 3          1  329.233227  637.222758  160.063898    78.174221
# 4          1  290.625000  353.926702  104.861111    47.120419

# %%
# def view_page_1(number):
#     print(str(df_resize['doc_name'][number]))
#     im = cv2.imread(str(df_resize.values[number][0]))
#     class_index = df_resize.iloc[number].zone_type
    
#     bb = create_bb_array(df_resize.values[number][4:], class_index)
    
#     _, y_ind = create_mask(bb, im, class_index)

#     rect = plt.Rectangle((bb[0], bb[1]), bb[2], bb[3],fill=False, color='red')
#     fig, ax = plt.subplots(1,2,figsize=(10,7))
#     ax[0].imshow(im)
#     ax[0].add_patch(rect)
#     ax[1].imshow(y_ind)
#     plt.show()

# %%
# view_page_1(3)

# %% [markdown]
# Выделим из сего набора данных только изображения содержащие логотипы.

# %%
df_logo = df_resize.loc[(df_resize['zone_type']==class_names['DLLogo'])]
df_logo.head(3)
# Out:
#                                          doc_name  old_width  old_height  \
# 13         ../pages/source_prepare/obh31f00_3.tif       1200        1575
# 20  ../pages/source_prepare/rkc33a00-page02_1.tif       2400        3150
# 24  ../pages/source_prepare/cxk72e00-page03_1.tif       2560        3168
#
#     zone_type   zone_col    zone_row  zone_width  zone_height
# 13          2  106.50000   58.412698      66.000    39.111111
# 20          2   45.75000  106.920635      57.750    58.666667
# 24          2  263.90625   30.555556      73.125    45.959596

# %% [markdown]
# Выделим из сего набора данных только изображения содержащие подписи.

# %%
# df_signature = df_resize.loc[(df_resize['zone_type']==class_names['DLSignature'])]
# df_signature.head(3)

# %% [markdown]
# Исходное изображение имеет очень большой размер. т.о. оно не помещается в нейронную сеть. Так что оно помещается в нейронную сеть целиком. Для того чтобы обойти это ограничение разрежем изображение на квадраты размером `win_size` (224) c небольшим взаимным перекрытием. И в таком виде будем подавать модель в сеть.

# %% [markdown]
# Определим координаты ограничивающий прямоугольников.

# %%
steps_x = math.ceil(IM_SIZE[0]/100) #/win_size
steps_y = math.ceil(IM_SIZE[1]/100) #/win_size

# запомнить позицию каждого квадрата.
step_x = 100 #math.floor(IM_SIZE[0]/math.ceil(IM_SIZE[0]/win_size)) 
step_y = 100 #math.floor(IM_SIZE[1]/math.ceil(IM_SIZE[1]/win_size)) 


step_y, step_x
win_coords = [ ]
for i in range(steps_y):
    for j in range(steps_x):
        pos_x = step_x*j
        pos_y = step_y*i
        if pos_x+win_size> IM_SIZE[0]:
            pos_x = IM_SIZE[0]-win_size
        if pos_y+win_size> IM_SIZE[1]:
            pos_y = IM_SIZE[1]-win_size   
        win_coords.append([pos_y, pos_x, win_size, win_size])

# %%
# Процедура для разбиения изображения на квадраты

def split_image(img, bbx=None, class_index=1):
    is_not_bbx=False
    if not bbx:
        is_not_bbx=True
        bbx = np.array([0,-1,-1,-1,-1], dtype='float')
    _, mask = create_mask(bbx, img, class_index)
# разделем изображение на составные части и возращем кусочки small_imgs and small_bbx
    img_combined = np.concatenate([img, mask[..., None]], axis=2)
    X_batch=[]
    y_batch=[]
    for coord in win_coords:
        combined = img_combined[coord[0]:(coord[0]+coord[2]), coord[1]:(coord[1]+coord[3])]
        X_batch.append(combined[...,:3])
        bb = mask_to_bb(combined[...,3])
        y_batch.append(bb)

    X_batch = np.array(X_batch, dtype='float') /255.0
    y_batch = np.array(y_batch, dtype='float')

    if is_not_bbx:
        return X_batch
    else:    
        return X_batch, y_batch

# %%
def show_result(sample_imgs, scores, sample_bbx):
    fig = plt.figure(figsize=(15, 20))
    for j in range(len(sample_imgs)):
        ax = fig.add_subplot(steps_y, steps_x, j+1)
        ax.imshow(sample_imgs[j])
        bb = sample_bbx[j]
        # print(bb)
        wr = bb[2]*win_size
        hc = bb[3]*win_size
        tr = bb[0]*win_size - wr/2
        tc = bb[1]*win_size - hc/2
        rect = plt.Rectangle((tr, tc), wr, hc,fill=False, color='red')
        ax.add_patch(rect)
        ax.title.set_text(f'{scores[j]:.2f}') 
        # print(sigmoid(bb[0]))
        plt.xticks([]), plt.yticks([])
    plt.show()

# %% [markdown]
# ### Генератор.
#  Через него будем подавать изображения в нейронку. Т.к. подаем изображение почастям, то получается так, что буквально 2-3  участка изображения будут содержать логотип, а остальные будут дудут пустыми. Выборка получается несбалансированной. Поэтому применим лайвхак. Будем выбирать только изображения содержащие логотипы и добавлять к ним 3 рандомно выбранные иизображения без объектов.

# %%
from albumentations import ShiftScaleRotate

# %%
def strong_aug(p=1.0):
    return ShiftScaleRotate(shift_limit=0.3, 
                                     scale_limit=0.3,
                                     rotate_limit=3,
                                     p=p, 
                                     border_mode=cv2.BORDER_CONSTANT)

# %%
def keras_generator(gen_df, batch_size = 1, is_test=False,is_augmentation=False):
    c = 0
    ind = np.arange(0,len(gen_df))
    random.shuffle(ind)
    augmentation = strong_aug(p=1.0)

    while True:
        X_batch = []
        y_batch = []

        for i in range(c,c + batch_size): # выполняется до тех пор пока не заполится массив.
          row = gen_df.values[ind[i]] # выдает случайный номер картинки. 
          img_name = row[0]

          class_index = row[3]
          bb = row[4:]
          img = cv2.imread(str(img_name))
          img  = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

          # создаем маску из bb?,steps_y
          _, mask = create_mask(bb, img, class_index)
          combined = np.concatenate([img, mask[..., None]], axis=2)
          
          if is_test: # Выведем название картинки.
              print(img_name)
              for coord in win_coords:
                combined_chank = combined[coord[0]:(coord[0]+coord[2]), coord[1]:(coord[1]+coord[3])]
                bb = mask_to_bb(combined_chank[...,3])
                X_batch.append(combined_chank[...,:3])
                y_batch.append(bb)
          else:
          #   Будем брать произвольные квадраты, в которых наших изображений нет. 
              max_void_tyles = 3

              while max_void_tyles > 0:
                  i = random.randint(0, len(win_coords)-1)
                  combined_chank = combined[win_coords[i][0]:(win_coords[i][0]+win_coords[i][2]), win_coords[i][1]:(win_coords[i][1]+win_coords[i][3])]
                  bb = mask_to_bb(combined_chank[...,3])
                  if bb[0]== 0:
                    X_batch.append(combined_chank[...,:3])
                    y_batch.append(bb)
                    max_void_tyles-=1
          # Выбираем только box-ы в которых изображение присутствует.
              for coord in win_coords:
                  combined_chank = combined[coord[0]:(coord[0]+coord[2]), coord[1]:(coord[1]+coord[3])]
                  if is_augmentation==True:
                    data = {'image': combined_chank}
                    augmented = augmentation(**data)
                    combined_chank = augmented["image"]
                  bb = mask_to_bb(combined_chank[...,3])
                  if bb[0]==1:
                    X_batch.append(combined_chank[...,:3])
                    y_batch.append(bb)

        X_batch = np.array(X_batch, dtype='float') /255.0
        y_batch = np.array(y_batch, dtype='float')
        
        c += batch_size
        if(c + batch_size >= len(ind)):
            c = 0
            random.shuffle(ind)

        yield X_batch, (y_batch[:,0], y_batch[:,1:])

# %%
for X_test, y_test in keras_generator(df_logo,batch_size=1,is_augmentation=True):
  break

show_result(X_test, y_test[0],y_test[1])

# %%
test_count = math.floor(len(df_logo)*0.2)
# test_count
train_logo_df = df_logo.iloc[:-test_count]
test_logo_df =  df_logo.iloc[-test_count:]

# %% [markdown]
# # Изображение мы разрезали. Теперь нужно наложить маску.

# %%
from keras.applications.mobilenet import MobileNet, preprocess_input
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
import matplotlib.patches as patches
from keras.applications.vgg19 import VGG19
from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.models import Model
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten,Dropout, Input,GlobalAveragePooling2D, BatchNormalization

# %%
WEIGHT_DECAY = 0.001

wd = tf.keras.regularizers.l2(WEIGHT_DECAY)

args = {'padding':'same', 'activation': 'relu','kernel_regularizer':wd}

# %%
base_model = ResNet50(input_shape=(win_size, win_size, 3), include_top=False, pooling='avg')

output = base_model.output

x = Dropout(0.3)(output)
out1 = tf.keras.layers.Dense(1, activation='sigmoid', name='score')(x) # Этим выводам нужно присвоить названия.
out2 = tf.keras.layers.Dense(4, name='bbx')(x)

model_logo = tf.keras.models.Model(inputs=base_model.input, outputs=[out1, out2])   
# model_custom = Model()

# %%
def loss(gt, pred):
    intersections = 0
    unions = 0
    diff_width = np.minimum(gt[:,0] + gt[:,2], pred[:,0] + pred[:,2]) - np.maximum(gt[:,0], pred[:,2])
    diff_height = np.minimum(gt[:,1] + gt[:,3], pred[:,1] + pred[:,3]) - np.maximum(gt[:,1], pred[:,3])
    intersection = diff_width * diff_height
    
    # Compute union
    area_gt = gt[:,2] * gt[:,3]
    area_pred = pred[:,2] * pred[:,3]
    union = area_gt + area_pred - intersection

    # Compute intersection and union over multiple boxes
    for j, _ in enumerate(union):
        if union[j] > 0 and intersection[j] > 0 and union[j] >= intersection[j]:
            intersections += intersection[j]
            unions += union[j]

    # Compute IOU. Use 1e-8 to prevent division by zero
    iou = np.round(intersections / (unions + 1e-8), 4)
    iou = iou.astype(np.float32)
    return iou

def IoU(y_true, y_pred):
    iou = tf.py_function(loss, [y_true, y_pred], tf.float32)
    return iou

# %%
model_logo.compile(optimizer='Adam', 
              loss={'score':'binary_crossentropy', 'bbx':'mse'},
              metrics={'score': 'accuracy', 'bbx':IoU},#tf.keras.metrics.MeanIoU(num_classes=1)},
              loss_weights={'score': 1.0, 'bbx':10.0})

# %%
checkpoint_best_IoU = tf.keras.callbacks.ModelCheckpoint('models/model_logo_15_bestIoU.h5',
                                                  monitor='val_bbx_IoU',
                                                  mode='max',
                                                  save_best_only=True,
                                                  save_weights_only=False,
                                                  save_freq='epoch',
                                                  verbose=1
                                                 )
checkpoint_best_Loss = tf.keras.callbacks.ModelCheckpoint('models/model_logo_bestLoss.h5',
                                                  monitor='val_loss',
                                                  mode='auto',
                                                  save_best_only=True,
                                                  save_weights_only=False,
                                                  save_freq='epoch',
                                                  verbose=1
                                                 )

# %%
NUM_EPOCHS = 100

history = model_logo.fit(keras_generator(train_logo_df,batch_size=1,is_augmentation=True),
                       steps_per_epoch=(len(train_logo_df)),
                       epochs=NUM_EPOCHS,
                       validation_data=keras_generator(test_logo_df,batch_size=1),
                       validation_steps=(len(test_logo_df)), 
                       shuffle=True,
                       callbacks = [checkpoint_best_IoU,checkpoint_best_Loss],
                       verbose=1,
                       )
# Out:
# Epoch 1/100
# 52/52 [==============================] - 18s 351ms/step - loss: 0.4296 - score_loss: 0.1842 - bbx_loss: 0.0245 - score_accuracy: 0.9199 - bbx_IoU: 0.2162 - val_loss: 0.4710 - val_score_loss: 0.2569 - val_bbx_loss: 0.0214 - val_score_accuracy: 0.9200 - val_bbx_IoU: 0.2630
#
# Epoch 00001: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00001: val_loss did not improve from 0.23662
# Epoch 2/100
# 52/52 [==============================] - 18s 343ms/step - loss: 0.3797 - score_loss: 0.1696 - bbx_loss: 0.0210 - score_accuracy: 0.9293 - bbx_IoU: 0.1949 - val_loss: 0.6872 - val_score_loss: 0.3350 - val_bbx_loss: 0.0352 - val_score_accuracy: 0.8649 - val_bbx_IoU: 0.1921
#
# Epoch 00002: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00002: val_loss did not improve from 0.23662
# Epoch 3/100
# 52/52 [==============================] - 19s 368ms/step - loss: 0.4076 - score_loss: 0.1643 - bbx_loss: 0.0243 - score_accuracy: 0.9404 - bbx_IoU: 0.1669 - val_loss: 0.9970 - val_score_loss: 0.6248 - val_bbx_loss: 0.0372 - val_score_accuracy: 0.7564 - val_bbx_IoU: 0.1984
#
# Epoch 00003: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00003: val_loss did not improve from 0.23662
# Epoch 4/100
# 52/52 [==============================] - 15s 291ms/step - loss: 0.3850 - score_loss: 0.1216 - bbx_loss: 0.0263 - score_accuracy: 0.9570 - bbx_IoU: 0.2001 - val_loss: 0.5093 - val_score_loss: 0.1877 - val_bbx_loss: 0.0322 - val_score_accuracy: 0.9242 - val_bbx_IoU: 0.1200
#
# Epoch 00004: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00004: val_loss did not improve from 0.23662
# Epoch 5/100
# 52/52 [==============================] - 25s 494ms/step - loss: 0.2795 - score_loss: 0.0749 - bbx_loss: 0.0205 - score_accuracy: 0.9861 - bbx_IoU: 0.1924 - val_loss: 0.6429 - val_score_loss: 0.4822 - val_bbx_loss: 0.0161 - val_score_accuracy: 0.8243 - val_bbx_IoU: 0.1110
#
# Epoch 00005: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00005: val_loss did not improve from 0.23662
# Epoch 6/100
# 52/52 [==============================] - 18s 341ms/step - loss: 0.2312 - score_loss: 0.0901 - bbx_loss: 0.0141 - score_accuracy: 0.9788 - bbx_IoU: 0.2444 - val_loss: 0.4077 - val_score_loss: 0.2448 - val_bbx_loss: 0.0163 - val_score_accuracy: 0.8947 - val_bbx_IoU: 0.2512
#
# Epoch 00006: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00006: val_loss did not improve from 0.23662
# Epoch 7/100
# 52/52 [==============================] - 13s 241ms/step - loss: 0.1811 - score_loss: 0.0388 - bbx_loss: 0.0142 - score_accuracy: 0.9860 - bbx_IoU: 0.2914 - val_loss: 0.4875 - val_score_loss: 0.2855 - val_bbx_loss: 0.0202 - val_score_accuracy: 0.8919 - val_bbx_IoU: 0.0965
#
# Epoch 00007: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00007: val_loss did not improve from 0.23662
# Epoch 8/100
# 52/52 [==============================] - 12s 225ms/step - loss: 0.2582 - score_loss: 0.0893 - bbx_loss: 0.0169 - score_accuracy: 0.9576 - bbx_IoU: 0.2430 - val_loss: 1.3189 - val_score_loss: 0.5264 - val_bbx_loss: 0.0793 - val_score_accuracy: 0.8462 - val_bbx_IoU: 0.2771
#
# Epoch 00008: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00008: val_loss did not improve from 0.23662
# Epoch 9/100
# 52/52 [==============================] - 21s 406ms/step - loss: 0.1369 - score_loss: 0.0301 - bbx_loss: 0.0107 - score_accuracy: 0.9930 - bbx_IoU: 0.2385 - val_loss: 0.3098 - val_score_loss: 0.1001 - val_bbx_loss: 0.0210 - val_score_accuracy: 0.9851 - val_bbx_IoU: 0.1579
#
# Epoch 00009: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00009: val_loss did not improve from 0.23662
# Epoch 10/100
# 52/52 [==============================] - 12s 225ms/step - loss: 0.1530 - score_loss: 0.0320 - bbx_loss: 0.0121 - score_accuracy: 0.9965 - bbx_IoU: 0.2516 - val_loss: 0.3188 - val_score_loss: 0.1591 - val_bbx_loss: 0.0160 - val_score_accuracy: 0.9726 - val_bbx_IoU: 0.1073
#
# Epoch 00010: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00010: val_loss did not improve from 0.23662
# Epoch 11/100
# 52/52 [==============================] - 14s 271ms/step - loss: 0.1765 - score_loss: 0.0771 - bbx_loss: 0.0099 - score_accuracy: 0.9741 - bbx_IoU: 0.1899 - val_loss: 0.5331 - val_score_loss: 0.3490 - val_bbx_loss: 0.0184 - val_score_accuracy: 0.8378 - val_bbx_IoU: 0.2059
#
# Epoch 00011: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00011: val_loss did not improve from 0.23662
# Epoch 12/100
# 52/52 [==============================] - 19s 360ms/step - loss: 0.1548 - score_loss: 0.0614 - bbx_loss: 0.0093 - score_accuracy: 0.9818 - bbx_IoU: 0.2633 - val_loss: 0.4457 - val_score_loss: 0.2113 - val_bbx_loss: 0.0234 - val_score_accuracy: 0.9211 - val_bbx_IoU: 0.0556
#
# Epoch 00012: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00012: val_loss did not improve from 0.23662
# Epoch 13/100
# 52/52 [==============================] - 12s 228ms/step - loss: 0.2030 - score_loss: 0.0672 - bbx_loss: 0.0136 - score_accuracy: 0.9719 - bbx_IoU: 0.2080 - val_loss: 0.6174 - val_score_loss: 0.1411 - val_bbx_loss: 0.0476 - val_score_accuracy: 0.9859 - val_bbx_IoU: 0.0695
#
# Epoch 00013: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00013: val_loss did not improve from 0.23662
# Epoch 14/100
# 52/52 [==============================] - 11s 215ms/step - loss: 0.2410 - score_loss: 0.0992 - bbx_loss: 0.0142 - score_accuracy: 0.9759 - bbx_IoU: 0.2328 - val_loss: 0.9434 - val_score_loss: 0.5646 - val_bbx_loss: 0.0379 - val_score_accuracy: 0.9028 - val_bbx_IoU: 0.2118
#
# Epoch 00014: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00014: val_loss did not improve from 0.23662
# Epoch 15/100
# 52/52 [==============================] - 11s 209ms/step - loss: 0.1319 - score_loss: 0.0348 - bbx_loss: 0.0097 - score_accuracy: 0.9858 - bbx_IoU: 0.2188 - val_loss: 0.2757 - val_score_loss: 0.0945 - val_bbx_loss: 0.0181 - val_score_accuracy: 0.9600 - val_bbx_IoU: 0.2220
#
# Epoch 00015: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00015: val_loss did not improve from 0.23662
# Epoch 16/100
# 52/52 [==============================] - 11s 207ms/step - loss: 0.1156 - score_loss: 0.0154 - bbx_loss: 0.0100 - score_accuracy: 0.9965 - bbx_IoU: 0.2390 - val_loss: 0.4279 - val_score_loss: 0.3276 - val_bbx_loss: 0.0100 - val_score_accuracy: 0.8701 - val_bbx_IoU: 0.1202
#
# Epoch 00016: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00016: val_loss did not improve from 0.23662
# Epoch 17/100
# 52/52 [==============================] - 11s 212ms/step - loss: 0.1069 - score_loss: 0.0210 - bbx_loss: 0.0086 - score_accuracy: 0.9928 - bbx_IoU: 0.2730 - val_loss: 0.9452 - val_score_loss: 0.7941 - val_bbx_loss: 0.0151 - val_score_accuracy: 0.7463 - val_bbx_IoU: 0.1577
#
# Epoch 00017: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00017: val_loss did not improve from 0.23662
# Epoch 18/100
# 52/52 [==============================] - 12s 231ms/step - loss: 0.0685 - score_loss: 0.0106 - bbx_loss: 0.0058 - score_accuracy: 1.0000 - bbx_IoU: 0.2827 - val_loss: 0.1519 - val_score_loss: 0.0736 - val_bbx_loss: 0.0078 - val_score_accuracy: 0.9868 - val_bbx_IoU: 0.1788
#
# Epoch 00018: val_bbx_IoU did not improve from 0.30579
#
# Epoch 00018: val_loss improved from 0.23662 to 0.15187, saving model to models/model_logo_15_bestLoss.h5
# /home/sergey/anaconda3/envs/imageai_env/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 19/100
# 52/52 [==============================] - 12s 240ms/step - loss: 0.0720 - score_loss: 0.0132 - bbx_loss: 0.0059 - score_accuracy: 0.9931 - bbx_IoU: 0.3069 - val_loss: 0.1147 - val_score_loss: 0.0629 - val_bbx_loss: 0.0052 - val_score_accuracy: 0.9865 - val_bbx_IoU: 0.3259
#
# Epoch 00019: val_bbx_IoU improved from 0.30579 to 0.32588, saving model to models/model_logo_15_bestIoU.h5
#
# Epoch 00019: val_loss improved from 0.15187 to 0.11465, saving model to models/model_logo_15_bestLoss.h5
# Epoch 20/100
# 52/52 [==============================] - 10s 200ms/step - loss: 0.0802 - score_loss: 0.0156 - bbx_loss: 0.0065 - score_accuracy: 0.9928 - bbx_IoU: 0.2952 - val_loss: 0.3485 - val_score_loss: 0.2749 - val_bbx_loss: 0.0074 - val_score_accuracy: 0.9041 - val_bbx_IoU: 0.3779
#
# Epoch 00020: val_bbx_IoU improved from 0.32588 to 0.37788, saving model to models/model_logo_15_bestIoU.h5
#
# Epoch 00020: val_loss did not improve from 0.11465
# Epoch 21/100
# 52/52 [==============================] - 11s 203ms/step - loss: 0.0625 - score_loss: 0.0117 - bbx_loss: 0.0051 - score_accuracy: 0.9965 - bbx_IoU: 0.3219 - val_loss: 0.2266 - val_score_loss: 0.1175 - val_bbx_loss: 0.0109 - val_score_accuracy: 0.9577 - val_bbx_IoU: 0.1028
#
# Epoch 00021: val_bbx_IoU did not improve from 0.37788
#
# Epoch 00021: val_loss did not improve from 0.11465
# Epoch 22/100
# 52/52 [==============================] - 12s 225ms/step - loss: 0.1492 - score_loss: 0.0423 - bbx_loss: 0.0107 - score_accuracy: 0.9825 - bbx_IoU: 0.2545 - val_loss: 0.4795 - val_score_loss: 0.0575 - val_bbx_loss: 0.0422 - val_score_accuracy: 0.9722 - val_bbx_IoU: 0.1243
#
# Epoch 00022: val_bbx_IoU did not improve from 0.37788
#
# Epoch 00022: val_loss did not improve from 0.11465
# Epoch 23/100
# 52/52 [==============================] - 14s 277ms/step - loss: 0.1287 - score_loss: 0.0386 - bbx_loss: 0.0090 - score_accuracy: 0.9894 - bbx_IoU: 0.2229 - val_loss: 0.2280 - val_score_loss: 0.1525 - val_bbx_loss: 0.0076 - val_score_accuracy: 0.9342 - val_bbx_IoU: 0.2927
#
# Epoch 00023: val_bbx_IoU did not improve from 0.37788
#
# Epoch 00023: val_loss did not improve from 0.11465
# Epoch 24/100
# 52/52 [==============================] - 10s 200ms/step - loss: 0.1202 - score_loss: 0.0423 - bbx_loss: 0.0078 - score_accuracy: 0.9817 - bbx_IoU: 0.2710 - val_loss: 0.1544 - val_score_loss: 0.0658 - val_bbx_loss: 0.0089 - val_score_accuracy: 0.9861 - val_bbx_IoU: 0.4508
#
# Epoch 00024: val_bbx_IoU improved from 0.37788 to 0.45078, saving model to models/model_logo_15_bestIoU.h5
#
# Epoch 00024: val_loss did not improve from 0.11465
# Epoch 25/100
# 52/52 [==============================] - 11s 208ms/step - loss: 0.1589 - score_loss: 0.0207 - bbx_loss: 0.0138 - score_accuracy: 0.9931 - bbx_IoU: 0.2447 - val_loss: 0.3813 - val_score_loss: 0.1907 - val_bbx_loss: 0.0191 - val_score_accuracy: 0.9333 - val_bbx_IoU: 0.0944
#
# Epoch 00025: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00025: val_loss did not improve from 0.11465
# Epoch 26/100
# 52/52 [==============================] - 10s 201ms/step - loss: 0.1207 - score_loss: 0.0316 - bbx_loss: 0.0089 - score_accuracy: 0.9891 - bbx_IoU: 0.2987 - val_loss: 0.4855 - val_score_loss: 0.3002 - val_bbx_loss: 0.0185 - val_score_accuracy: 0.8889 - val_bbx_IoU: 0.1343
#
# Epoch 00026: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00026: val_loss did not improve from 0.11465
# Epoch 27/100
# 52/52 [==============================] - 15s 287ms/step - loss: 0.1281 - score_loss: 0.0451 - bbx_loss: 0.0083 - score_accuracy: 0.9896 - bbx_IoU: 0.2673 - val_loss: 0.7083 - val_score_loss: 0.5254 - val_bbx_loss: 0.0183 - val_score_accuracy: 0.8649 - val_bbx_IoU: 0.0995
#
# Epoch 00027: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00027: val_loss did not improve from 0.11465
# Epoch 28/100
# 52/52 [==============================] - 18s 343ms/step - loss: 0.0858 - score_loss: 0.0120 - bbx_loss: 0.0074 - score_accuracy: 0.9965 - bbx_IoU: 0.2967 - val_loss: 0.1811 - val_score_loss: 0.0587 - val_bbx_loss: 0.0122 - val_score_accuracy: 0.9863 - val_bbx_IoU: 0.1808
#
# Epoch 00028: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00028: val_loss did not improve from 0.11465
# Epoch 29/100
# 52/52 [==============================] - 16s 315ms/step - loss: 0.0669 - score_loss: 0.0067 - bbx_loss: 0.0060 - score_accuracy: 1.0000 - bbx_IoU: 0.3050 - val_loss: 0.3242 - val_score_loss: 0.2236 - val_bbx_loss: 0.0101 - val_score_accuracy: 0.8800 - val_bbx_IoU: 0.2850
#
# Epoch 00029: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00029: val_loss did not improve from 0.11465
# Epoch 30/100
# 52/52 [==============================] - 21s 412ms/step - loss: 0.0403 - score_loss: 0.0033 - bbx_loss: 0.0037 - score_accuracy: 1.0000 - bbx_IoU: 0.2724 - val_loss: 0.3214 - val_score_loss: 0.2373 - val_bbx_loss: 0.0084 - val_score_accuracy: 0.8933 - val_bbx_IoU: 0.3384
#
# Epoch 00030: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00030: val_loss did not improve from 0.11465
# Epoch 31/100
# 52/52 [==============================] - 19s 360ms/step - loss: 0.0323 - score_loss: 0.0035 - bbx_loss: 0.0029 - score_accuracy: 1.0000 - bbx_IoU: 0.3509 - val_loss: 0.0536 - val_score_loss: 0.0297 - val_bbx_loss: 0.0024 - val_score_accuracy: 0.9853 - val_bbx_IoU: 0.3651
#
# Epoch 00031: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00031: val_loss improved from 0.11465 to 0.05361, saving model to models/model_logo_15_bestLoss.h5
# Epoch 32/100
# 52/52 [==============================] - 18s 345ms/step - loss: 0.0766 - score_loss: 0.0095 - bbx_loss: 0.0067 - score_accuracy: 0.9965 - bbx_IoU: 0.3228 - val_loss: 0.0751 - val_score_loss: 0.0266 - val_bbx_loss: 0.0049 - val_score_accuracy: 1.0000 - val_bbx_IoU: 0.3394
#
# Epoch 00032: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00032: val_loss did not improve from 0.05361
# Epoch 33/100
# 52/52 [==============================] - 17s 325ms/step - loss: 0.0481 - score_loss: 0.0021 - bbx_loss: 0.0046 - score_accuracy: 1.0000 - bbx_IoU: 0.3371 - val_loss: 0.2072 - val_score_loss: 0.1252 - val_bbx_loss: 0.0082 - val_score_accuracy: 0.9481 - val_bbx_IoU: 0.2540
#
# Epoch 00033: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00033: val_loss did not improve from 0.05361
# Epoch 34/100
# 52/52 [==============================] - 13s 242ms/step - loss: 0.1914 - score_loss: 0.1066 - bbx_loss: 0.0085 - score_accuracy: 0.9716 - bbx_IoU: 0.2622 - val_loss: 0.8854 - val_score_loss: 0.2921 - val_bbx_loss: 0.0593 - val_score_accuracy: 0.9178 - val_bbx_IoU: 0.2146
#
# Epoch 00034: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00034: val_loss did not improve from 0.05361
# Epoch 35/100
# 52/52 [==============================] - 11s 210ms/step - loss: 0.1255 - score_loss: 0.0262 - bbx_loss: 0.0099 - score_accuracy: 0.9932 - bbx_IoU: 0.2929 - val_loss: 0.2480 - val_score_loss: 0.1579 - val_bbx_loss: 0.0090 - val_score_accuracy: 0.9375 - val_bbx_IoU: 0.2631
#
# Epoch 00035: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00035: val_loss did not improve from 0.05361
# Epoch 36/100
# 52/52 [==============================] - 10s 201ms/step - loss: 0.1377 - score_loss: 0.0304 - bbx_loss: 0.0107 - score_accuracy: 0.9892 - bbx_IoU: 0.2551 - val_loss: 0.2606 - val_score_loss: 0.0818 - val_bbx_loss: 0.0179 - val_score_accuracy: 0.9706 - val_bbx_IoU: 0.1765
#
# Epoch 00036: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00036: val_loss did not improve from 0.05361
# Epoch 37/100
# 52/52 [==============================] - 11s 215ms/step - loss: 0.1267 - score_loss: 0.0394 - bbx_loss: 0.0087 - score_accuracy: 0.9859 - bbx_IoU: 0.2649 - val_loss: 0.4730 - val_score_loss: 0.1632 - val_bbx_loss: 0.0310 - val_score_accuracy: 0.9178 - val_bbx_IoU: 0.1181
#
# Epoch 00037: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00037: val_loss did not improve from 0.05361
# Epoch 38/100
# 52/52 [==============================] - 11s 214ms/step - loss: 0.1981 - score_loss: 0.0846 - bbx_loss: 0.0114 - score_accuracy: 0.9783 - bbx_IoU: 0.2309 - val_loss: 12.3423 - val_score_loss: 9.7397 - val_bbx_loss: 0.2603 - val_score_accuracy: 0.5205 - val_bbx_IoU: 0.0072
#
# Epoch 00038: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00038: val_loss did not improve from 0.05361
# Epoch 39/100
# 52/52 [==============================] - 11s 205ms/step - loss: 0.1830 - score_loss: 0.0527 - bbx_loss: 0.0130 - score_accuracy: 0.9858 - bbx_IoU: 0.2288 - val_loss: 1.4114 - val_score_loss: 1.0137 - val_bbx_loss: 0.0398 - val_score_accuracy: 0.6316 - val_bbx_IoU: 0.1029
#
# Epoch 00039: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00039: val_loss did not improve from 0.05361
# Epoch 40/100
# 52/52 [==============================] - 12s 226ms/step - loss: 0.1149 - score_loss: 0.0232 - bbx_loss: 0.0092 - score_accuracy: 0.9896 - bbx_IoU: 0.2958 - val_loss: 0.7712 - val_score_loss: 0.5104 - val_bbx_loss: 0.0261 - val_score_accuracy: 0.8382 - val_bbx_IoU: 0.1009
#
# Epoch 00040: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00040: val_loss did not improve from 0.05361
# Epoch 41/100
# 52/52 [==============================] - 13s 246ms/step - loss: 0.1059 - score_loss: 0.0379 - bbx_loss: 0.0068 - score_accuracy: 0.9928 - bbx_IoU: 0.2851 - val_loss: 3.6374 - val_score_loss: 2.5480 - val_bbx_loss: 0.1089 - val_score_accuracy: 0.7397 - val_bbx_IoU: 0.1041
#
# Epoch 00041: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00041: val_loss did not improve from 0.05361
# Epoch 42/100
# 52/52 [==============================] - 12s 226ms/step - loss: 0.1826 - score_loss: 0.0842 - bbx_loss: 0.0098 - score_accuracy: 0.9858 - bbx_IoU: 0.2432 - val_loss: 0.5609 - val_score_loss: 0.2032 - val_bbx_loss: 0.0358 - val_score_accuracy: 0.9429 - val_bbx_IoU: 0.2629
#
# Epoch 00042: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00042: val_loss did not improve from 0.05361
# Epoch 43/100
# 52/52 [==============================] - 11s 217ms/step - loss: 0.2051 - score_loss: 0.0605 - bbx_loss: 0.0145 - score_accuracy: 0.9867 - bbx_IoU: 0.2165 - val_loss: 1.0438 - val_score_loss: 0.7548 - val_bbx_loss: 0.0289 - val_score_accuracy: 0.8219 - val_bbx_IoU: 0.3337
#
# Epoch 00043: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00043: val_loss did not improve from 0.05361
# Epoch 44/100
# 52/52 [==============================] - 11s 203ms/step - loss: 0.1305 - score_loss: 0.0497 - bbx_loss: 0.0081 - score_accuracy: 0.9784 - bbx_IoU: 0.2663 - val_loss: 0.8179 - val_score_loss: 0.4895 - val_bbx_loss: 0.0328 - val_score_accuracy: 0.8514 - val_bbx_IoU: 0.1103
#
# Epoch 00044: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00044: val_loss did not improve from 0.05361
# Epoch 45/100
# 52/52 [==============================] - 11s 207ms/step - loss: 0.0643 - score_loss: 0.0119 - bbx_loss: 0.0052 - score_accuracy: 0.9965 - bbx_IoU: 0.2937 - val_loss: 0.4198 - val_score_loss: 0.2307 - val_bbx_loss: 0.0189 - val_score_accuracy: 0.8846 - val_bbx_IoU: 0.1651
#
# Epoch 00045: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00045: val_loss did not improve from 0.05361
# Epoch 46/100
# 52/52 [==============================] - 11s 210ms/step - loss: 0.0616 - score_loss: 0.0094 - bbx_loss: 0.0052 - score_accuracy: 1.0000 - bbx_IoU: 0.2618 - val_loss: 0.2410 - val_score_loss: 0.1239 - val_bbx_loss: 0.0117 - val_score_accuracy: 0.9565 - val_bbx_IoU: 0.1344
#
# Epoch 00046: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00046: val_loss did not improve from 0.05361
# Epoch 47/100
# 52/52 [==============================] - 11s 215ms/step - loss: 0.0609 - score_loss: 0.0082 - bbx_loss: 0.0053 - score_accuracy: 1.0000 - bbx_IoU: 0.3002 - val_loss: 0.9223 - val_score_loss: 0.7829 - val_bbx_loss: 0.0139 - val_score_accuracy: 0.8442 - val_bbx_IoU: 0.3811
#
# Epoch 00047: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00047: val_loss did not improve from 0.05361
# Epoch 48/100
# 52/52 [==============================] - 11s 205ms/step - loss: 0.0645 - score_loss: 0.0180 - bbx_loss: 0.0047 - score_accuracy: 0.9930 - bbx_IoU: 0.3747 - val_loss: 0.7145 - val_score_loss: 0.4962 - val_bbx_loss: 0.0218 - val_score_accuracy: 0.8493 - val_bbx_IoU: 0.0790
#
# Epoch 00048: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00048: val_loss did not improve from 0.05361
# Epoch 49/100
# 52/52 [==============================] - 12s 233ms/step - loss: 0.1183 - score_loss: 0.0391 - bbx_loss: 0.0079 - score_accuracy: 0.9891 - bbx_IoU: 0.2558 - val_loss: 0.1183 - val_score_loss: 0.0195 - val_bbx_loss: 0.0099 - val_score_accuracy: 1.0000 - val_bbx_IoU: 0.1397
#
# Epoch 00049: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00049: val_loss did not improve from 0.05361
# Epoch 50/100
# 52/52 [==============================] - 15s 288ms/step - loss: 0.1539 - score_loss: 0.0670 - bbx_loss: 0.0087 - score_accuracy: 0.9789 - bbx_IoU: 0.2846 - val_loss: 0.1995 - val_score_loss: 0.1093 - val_bbx_loss: 0.0090 - val_score_accuracy: 0.9589 - val_bbx_IoU: 0.2891
#
# Epoch 00050: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00050: val_loss did not improve from 0.05361
# Epoch 51/100
# 52/52 [==============================] - 14s 260ms/step - loss: 0.1040 - score_loss: 0.0232 - bbx_loss: 0.0081 - score_accuracy: 0.9858 - bbx_IoU: 0.2727 - val_loss: 0.3424 - val_score_loss: 0.1487 - val_bbx_loss: 0.0194 - val_score_accuracy: 0.9733 - val_bbx_IoU: 0.3604
#
# Epoch 00051: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00051: val_loss did not improve from 0.05361
# Epoch 52/100
# 52/52 [==============================] - 13s 244ms/step - loss: 0.0672 - score_loss: 0.0087 - bbx_loss: 0.0059 - score_accuracy: 1.0000 - bbx_IoU: 0.2991 - val_loss: 0.2057 - val_score_loss: 0.1491 - val_bbx_loss: 0.0057 - val_score_accuracy: 0.9589 - val_bbx_IoU: 0.2934
#
# Epoch 00052: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00052: val_loss did not improve from 0.05361
# Epoch 53/100
# 52/52 [==============================] - 11s 214ms/step - loss: 0.0594 - score_loss: 0.0079 - bbx_loss: 0.0052 - score_accuracy: 0.9964 - bbx_IoU: 0.2798 - val_loss: 0.3267 - val_score_loss: 0.1995 - val_bbx_loss: 0.0127 - val_score_accuracy: 0.9459 - val_bbx_IoU: 0.0852
#
# Epoch 00053: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00053: val_loss did not improve from 0.05361
# Epoch 54/100
# 52/52 [==============================] - 11s 213ms/step - loss: 0.0571 - score_loss: 0.0141 - bbx_loss: 0.0043 - score_accuracy: 0.9928 - bbx_IoU: 0.3109 - val_loss: 0.4090 - val_score_loss: 0.2082 - val_bbx_loss: 0.0201 - val_score_accuracy: 0.9429 - val_bbx_IoU: 0.1467
#
# Epoch 00054: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00054: val_loss did not improve from 0.05361
# Epoch 55/100
# 52/52 [==============================] - 13s 248ms/step - loss: 0.0375 - score_loss: 0.0018 - bbx_loss: 0.0036 - score_accuracy: 1.0000 - bbx_IoU: 0.3043 - val_loss: 0.3275 - val_score_loss: 0.2026 - val_bbx_loss: 0.0125 - val_score_accuracy: 0.9571 - val_bbx_IoU: 0.1465
#
# Epoch 00055: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00055: val_loss did not improve from 0.05361
# Epoch 56/100
# 52/52 [==============================] - 12s 227ms/step - loss: 0.0753 - score_loss: 0.0160 - bbx_loss: 0.0059 - score_accuracy: 0.9929 - bbx_IoU: 0.2525 - val_loss: 2.6780 - val_score_loss: 0.4858 - val_bbx_loss: 0.2192 - val_score_accuracy: 0.9342 - val_bbx_IoU: 0.1209
#
# Epoch 00056: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00056: val_loss did not improve from 0.05361
# Epoch 57/100
# 52/52 [==============================] - 11s 217ms/step - loss: 0.1253 - score_loss: 0.0533 - bbx_loss: 0.0072 - score_accuracy: 0.9748 - bbx_IoU: 0.2643 - val_loss: 53.7865 - val_score_loss: 8.6678 - val_bbx_loss: 4.5119 - val_score_accuracy: 0.8194 - val_bbx_IoU: 0.0000e+00
#
# Epoch 00057: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00057: val_loss did not improve from 0.05361
# Epoch 58/100
# 52/52 [==============================] - 14s 263ms/step - loss: 0.4650 - score_loss: 0.2295 - bbx_loss: 0.0235 - score_accuracy: 0.9161 - bbx_IoU: 0.2280 - val_loss: 165.8413 - val_score_loss: 55.4690 - val_bbx_loss: 11.0372 - val_score_accuracy: 0.4868 - val_bbx_IoU: 0.0000e+00
#
# Epoch 00058: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00058: val_loss did not improve from 0.05361
# Epoch 59/100
# 52/52 [==============================] - 21s 400ms/step - loss: 0.1979 - score_loss: 0.0724 - bbx_loss: 0.0126 - score_accuracy: 0.9745 - bbx_IoU: 0.2246 - val_loss: 1.0193 - val_score_loss: 0.3919 - val_bbx_loss: 0.0627 - val_score_accuracy: 0.9394 - val_bbx_IoU: 0.1397
#
# Epoch 00059: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00059: val_loss did not improve from 0.05361
# Epoch 60/100
# 52/52 [==============================] - 12s 222ms/step - loss: 0.1435 - score_loss: 0.0560 - bbx_loss: 0.0087 - score_accuracy: 0.9857 - bbx_IoU: 0.2546 - val_loss: 1.0970 - val_score_loss: 0.8307 - val_bbx_loss: 0.0266 - val_score_accuracy: 0.7403 - val_bbx_IoU: 0.3133
#
# Epoch 00060: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00060: val_loss did not improve from 0.05361
# Epoch 61/100
# 52/52 [==============================] - 11s 208ms/step - loss: 0.1400 - score_loss: 0.0365 - bbx_loss: 0.0104 - score_accuracy: 0.9929 - bbx_IoU: 0.2449 - val_loss: 1.0335 - val_score_loss: 0.7905 - val_bbx_loss: 0.0243 - val_score_accuracy: 0.7397 - val_bbx_IoU: 0.1814
#
# Epoch 00061: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00061: val_loss did not improve from 0.05361
# Epoch 62/100
# 52/52 [==============================] - 10s 202ms/step - loss: 0.3183 - score_loss: 0.1384 - bbx_loss: 0.0180 - score_accuracy: 0.9568 - bbx_IoU: 0.2122 - val_loss: 1.7955 - val_score_loss: 1.5320 - val_bbx_loss: 0.0263 - val_score_accuracy: 0.7500 - val_bbx_IoU: 0.2550
#
# Epoch 00062: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00062: val_loss did not improve from 0.05361
# Epoch 63/100
# 52/52 [==============================] - 12s 225ms/step - loss: 0.2209 - score_loss: 0.0580 - bbx_loss: 0.0163 - score_accuracy: 0.9753 - bbx_IoU: 0.2029 - val_loss: 20.7624 - val_score_loss: 13.3240 - val_bbx_loss: 0.7438 - val_score_accuracy: 0.4706 - val_bbx_IoU: 0.0000e+00
#
# Epoch 00063: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00063: val_loss did not improve from 0.05361
# Epoch 64/100
# 52/52 [==============================] - 11s 210ms/step - loss: 0.5232 - score_loss: 0.2478 - bbx_loss: 0.0275 - score_accuracy: 0.9119 - bbx_IoU: 0.2058 - val_loss: 24.8488 - val_score_loss: 6.8564 - val_bbx_loss: 1.7992 - val_score_accuracy: 0.4730 - val_bbx_IoU: 0.3979
#
# Epoch 00064: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00064: val_loss did not improve from 0.05361
# Epoch 65/100
# 52/52 [==============================] - 10s 201ms/step - loss: 0.2538 - score_loss: 0.0761 - bbx_loss: 0.0178 - score_accuracy: 0.9709 - bbx_IoU: 0.2791 - val_loss: 0.6786 - val_score_loss: 0.2833 - val_bbx_loss: 0.0395 - val_score_accuracy: 0.8933 - val_bbx_IoU: 0.2200
#
# Epoch 00065: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00065: val_loss did not improve from 0.05361
# Epoch 66/100
# 52/52 [==============================] - 11s 204ms/step - loss: 0.1484 - score_loss: 0.0384 - bbx_loss: 0.0110 - score_accuracy: 0.9858 - bbx_IoU: 0.2167 - val_loss: 0.5123 - val_score_loss: 0.2238 - val_bbx_loss: 0.0289 - val_score_accuracy: 0.9315 - val_bbx_IoU: 0.2714
#
# Epoch 00066: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00066: val_loss did not improve from 0.05361
# Epoch 67/100
# 52/52 [==============================] - 11s 211ms/step - loss: 0.1198 - score_loss: 0.0256 - bbx_loss: 0.0094 - score_accuracy: 0.9929 - bbx_IoU: 0.3185 - val_loss: 0.4722 - val_score_loss: 0.3678 - val_bbx_loss: 0.0104 - val_score_accuracy: 0.8592 - val_bbx_IoU: 0.3075
#
# Epoch 00067: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00067: val_loss did not improve from 0.05361
# Epoch 68/100
# 52/52 [==============================] - 11s 206ms/step - loss: 0.1393 - score_loss: 0.0477 - bbx_loss: 0.0092 - score_accuracy: 0.9859 - bbx_IoU: 0.2930 - val_loss: 1.4684 - val_score_loss: 1.1305 - val_bbx_loss: 0.0338 - val_score_accuracy: 0.7568 - val_bbx_IoU: 0.0995
#
# Epoch 00068: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00068: val_loss did not improve from 0.05361
# Epoch 69/100
# 52/52 [==============================] - 11s 209ms/step - loss: 0.1069 - score_loss: 0.0221 - bbx_loss: 0.0085 - score_accuracy: 0.9965 - bbx_IoU: 0.1918 - val_loss: 0.1496 - val_score_loss: 0.0623 - val_bbx_loss: 0.0087 - val_score_accuracy: 0.9730 - val_bbx_IoU: 0.1289
#
# Epoch 00069: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00069: val_loss did not improve from 0.05361
# Epoch 70/100
# 52/52 [==============================] - 10s 201ms/step - loss: 0.0859 - score_loss: 0.0326 - bbx_loss: 0.0053 - score_accuracy: 0.9854 - bbx_IoU: 0.2563 - val_loss: 0.5563 - val_score_loss: 0.2821 - val_bbx_loss: 0.0274 - val_score_accuracy: 0.9467 - val_bbx_IoU: 0.2447
#
# Epoch 00070: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00070: val_loss did not improve from 0.05361
# Epoch 71/100
# 52/52 [==============================] - 11s 214ms/step - loss: 0.0656 - score_loss: 0.0134 - bbx_loss: 0.0052 - score_accuracy: 0.9964 - bbx_IoU: 0.3017 - val_loss: 0.8714 - val_score_loss: 0.7216 - val_bbx_loss: 0.0150 - val_score_accuracy: 0.8116 - val_bbx_IoU: 0.2715
#
# Epoch 00071: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00071: val_loss did not improve from 0.05361
# Epoch 72/100
# 52/52 [==============================] - 12s 230ms/step - loss: 0.0849 - score_loss: 0.0176 - bbx_loss: 0.0067 - score_accuracy: 0.9966 - bbx_IoU: 0.2742 - val_loss: 0.6112 - val_score_loss: 0.3416 - val_bbx_loss: 0.0270 - val_score_accuracy: 0.9079 - val_bbx_IoU: 0.1167
#
# Epoch 00072: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00072: val_loss did not improve from 0.05361
# Epoch 73/100
# 52/52 [==============================] - 11s 203ms/step - loss: 0.2135 - score_loss: 0.0769 - bbx_loss: 0.0137 - score_accuracy: 0.9682 - bbx_IoU: 0.1799 - val_loss: 3.3959 - val_score_loss: 0.7205 - val_bbx_loss: 0.2675 - val_score_accuracy: 0.9041 - val_bbx_IoU: 0.1106
#
# Epoch 00073: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00073: val_loss did not improve from 0.05361
# Epoch 74/100
# 52/52 [==============================] - 13s 246ms/step - loss: 0.1492 - score_loss: 0.0391 - bbx_loss: 0.0110 - score_accuracy: 0.9927 - bbx_IoU: 0.2889 - val_loss: 0.7867 - val_score_loss: 0.2885 - val_bbx_loss: 0.0498 - val_score_accuracy: 0.9437 - val_bbx_IoU: 0.1607
#
# Epoch 00074: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00074: val_loss did not improve from 0.05361
# Epoch 75/100
# 52/52 [==============================] - 14s 265ms/step - loss: 0.0915 - score_loss: 0.0262 - bbx_loss: 0.0065 - score_accuracy: 0.9927 - bbx_IoU: 0.2479 - val_loss: 0.5625 - val_score_loss: 0.4375 - val_bbx_loss: 0.0125 - val_score_accuracy: 0.9351 - val_bbx_IoU: 0.1089
#
# Epoch 00075: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00075: val_loss did not improve from 0.05361
# Epoch 76/100
# 52/52 [==============================] - 12s 237ms/step - loss: 0.0974 - score_loss: 0.0162 - bbx_loss: 0.0081 - score_accuracy: 0.9967 - bbx_IoU: 0.3050 - val_loss: 0.2737 - val_score_loss: 0.2112 - val_bbx_loss: 0.0062 - val_score_accuracy: 0.9718 - val_bbx_IoU: 0.2780
#
# Epoch 00076: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00076: val_loss did not improve from 0.05361
# Epoch 77/100
# 52/52 [==============================] - 11s 213ms/step - loss: 0.1112 - score_loss: 0.0373 - bbx_loss: 0.0074 - score_accuracy: 0.9890 - bbx_IoU: 0.3109 - val_loss: 0.3784 - val_score_loss: 0.2059 - val_bbx_loss: 0.0172 - val_score_accuracy: 0.9487 - val_bbx_IoU: 0.1862
#
# Epoch 00077: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00077: val_loss did not improve from 0.05361
# Epoch 78/100
# 52/52 [==============================] - 11s 208ms/step - loss: 0.1417 - score_loss: 0.0378 - bbx_loss: 0.0104 - score_accuracy: 0.9858 - bbx_IoU: 0.2680 - val_loss: 0.5359 - val_score_loss: 0.3456 - val_bbx_loss: 0.0190 - val_score_accuracy: 0.8592 - val_bbx_IoU: 0.1863
#
# Epoch 00078: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00078: val_loss did not improve from 0.05361
# Epoch 79/100
# 52/52 [==============================] - 11s 213ms/step - loss: 0.1727 - score_loss: 0.0741 - bbx_loss: 0.0099 - score_accuracy: 0.9727 - bbx_IoU: 0.2713 - val_loss: 0.5869 - val_score_loss: 0.3945 - val_bbx_loss: 0.0192 - val_score_accuracy: 0.8333 - val_bbx_IoU: 0.1895
#
# Epoch 00079: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00079: val_loss did not improve from 0.05361
# Epoch 80/100
# 52/52 [==============================] - 11s 210ms/step - loss: 0.1285 - score_loss: 0.0570 - bbx_loss: 0.0071 - score_accuracy: 0.9825 - bbx_IoU: 0.2587 - val_loss: 0.8193 - val_score_loss: 0.5626 - val_bbx_loss: 0.0257 - val_score_accuracy: 0.8194 - val_bbx_IoU: 0.1977
#
# Epoch 00080: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00080: val_loss did not improve from 0.05361
# Epoch 81/100
# 52/52 [==============================] - 12s 223ms/step - loss: 0.0625 - score_loss: 0.0125 - bbx_loss: 0.0050 - score_accuracy: 0.9963 - bbx_IoU: 0.3196 - val_loss: 1.0982 - val_score_loss: 0.9692 - val_bbx_loss: 0.0129 - val_score_accuracy: 0.6479 - val_bbx_IoU: 0.2376
#
# Epoch 00081: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00081: val_loss did not improve from 0.05361
# Epoch 82/100
# 52/52 [==============================] - 12s 238ms/step - loss: 0.1119 - score_loss: 0.0510 - bbx_loss: 0.0061 - score_accuracy: 0.9792 - bbx_IoU: 0.3340 - val_loss: 1.9895 - val_score_loss: 1.4808 - val_bbx_loss: 0.0509 - val_score_accuracy: 0.6447 - val_bbx_IoU: 0.3289
#
# Epoch 00082: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00082: val_loss did not improve from 0.05361
# Epoch 83/100
# 52/52 [==============================] - 12s 234ms/step - loss: 0.1475 - score_loss: 0.0642 - bbx_loss: 0.0083 - score_accuracy: 0.9745 - bbx_IoU: 0.2788 - val_loss: 0.5915 - val_score_loss: 0.2422 - val_bbx_loss: 0.0349 - val_score_accuracy: 0.9189 - val_bbx_IoU: 0.4498
#
# Epoch 00083: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00083: val_loss did not improve from 0.05361
# Epoch 84/100
# 52/52 [==============================] - 12s 232ms/step - loss: 0.1141 - score_loss: 0.0226 - bbx_loss: 0.0091 - score_accuracy: 0.9966 - bbx_IoU: 0.2988 - val_loss: 0.4659 - val_score_loss: 0.3124 - val_bbx_loss: 0.0153 - val_score_accuracy: 0.8553 - val_bbx_IoU: 0.2730
#
# Epoch 00084: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00084: val_loss did not improve from 0.05361
# Epoch 85/100
# 52/52 [==============================] - 12s 232ms/step - loss: 0.0656 - score_loss: 0.0178 - bbx_loss: 0.0048 - score_accuracy: 0.9895 - bbx_IoU: 0.3306 - val_loss: 0.2908 - val_score_loss: 0.1676 - val_bbx_loss: 0.0123 - val_score_accuracy: 0.9718 - val_bbx_IoU: 0.1305
#
# Epoch 00085: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00085: val_loss did not improve from 0.05361
# Epoch 86/100
# 52/52 [==============================] - 12s 227ms/step - loss: 0.0380 - score_loss: 0.0058 - bbx_loss: 0.0032 - score_accuracy: 1.0000 - bbx_IoU: 0.3271 - val_loss: 0.3371 - val_score_loss: 0.2535 - val_bbx_loss: 0.0084 - val_score_accuracy: 0.9167 - val_bbx_IoU: 0.3292
#
# Epoch 00086: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00086: val_loss did not improve from 0.05361
# Epoch 87/100
# 52/52 [==============================] - 12s 226ms/step - loss: 0.0475 - score_loss: 0.0097 - bbx_loss: 0.0038 - score_accuracy: 0.9964 - bbx_IoU: 0.3760 - val_loss: 0.2789 - val_score_loss: 0.2127 - val_bbx_loss: 0.0066 - val_score_accuracy: 0.9054 - val_bbx_IoU: 0.2140
#
# Epoch 00087: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00087: val_loss did not improve from 0.05361
# Epoch 88/100
# 52/52 [==============================] - 12s 228ms/step - loss: 0.0387 - score_loss: 0.0108 - bbx_loss: 0.0028 - score_accuracy: 0.9932 - bbx_IoU: 0.3598 - val_loss: 0.5687 - val_score_loss: 0.4746 - val_bbx_loss: 0.0094 - val_score_accuracy: 0.8649 - val_bbx_IoU: 0.1789
#
# Epoch 00088: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00088: val_loss did not improve from 0.05361
# Epoch 89/100
# 52/52 [==============================] - 11s 205ms/step - loss: 0.0328 - score_loss: 0.0053 - bbx_loss: 0.0027 - score_accuracy: 1.0000 - bbx_IoU: 0.3424 - val_loss: 0.0894 - val_score_loss: 0.0068 - val_bbx_loss: 0.0083 - val_score_accuracy: 1.0000 - val_bbx_IoU: 0.1994
#
# Epoch 00089: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00089: val_loss did not improve from 0.05361
# Epoch 90/100
# 52/52 [==============================] - 11s 211ms/step - loss: 0.0292 - score_loss: 0.0013 - bbx_loss: 0.0028 - score_accuracy: 1.0000 - bbx_IoU: 0.2777 - val_loss: 0.2996 - val_score_loss: 0.2333 - val_bbx_loss: 0.0066 - val_score_accuracy: 0.9000 - val_bbx_IoU: 0.3439
#
# Epoch 00090: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00090: val_loss did not improve from 0.05361
# Epoch 91/100
# 52/52 [==============================] - 12s 224ms/step - loss: 0.1717 - score_loss: 0.0822 - bbx_loss: 0.0089 - score_accuracy: 0.9764 - bbx_IoU: 0.2671 - val_loss: 0.4494 - val_score_loss: 0.2462 - val_bbx_loss: 0.0203 - val_score_accuracy: 0.9351 - val_bbx_IoU: 0.2683
#
# Epoch 00091: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00091: val_loss did not improve from 0.05361
# Epoch 92/100
# 52/52 [==============================] - 12s 222ms/step - loss: 0.0490 - score_loss: 0.0048 - bbx_loss: 0.0044 - score_accuracy: 1.0000 - bbx_IoU: 0.2974 - val_loss: 0.3830 - val_score_loss: 0.3096 - val_bbx_loss: 0.0073 - val_score_accuracy: 0.9437 - val_bbx_IoU: 0.2501
#
# Epoch 00092: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00092: val_loss did not improve from 0.05361
# Epoch 93/100
# 52/52 [==============================] - 12s 223ms/step - loss: 0.1365 - score_loss: 0.0632 - bbx_loss: 0.0073 - score_accuracy: 0.9891 - bbx_IoU: 0.2404 - val_loss: 0.6802 - val_score_loss: 0.1697 - val_bbx_loss: 0.0510 - val_score_accuracy: 0.9315 - val_bbx_IoU: 0.3756
#
# Epoch 00093: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00093: val_loss did not improve from 0.05361
# Epoch 94/100
# 52/52 [==============================] - 11s 217ms/step - loss: 0.1229 - score_loss: 0.0364 - bbx_loss: 0.0086 - score_accuracy: 0.9896 - bbx_IoU: 0.2599 - val_loss: 0.2426 - val_score_loss: 0.1370 - val_bbx_loss: 0.0106 - val_score_accuracy: 0.9565 - val_bbx_IoU: 0.1168
#
# Epoch 00094: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00094: val_loss did not improve from 0.05361
# Epoch 95/100
# 52/52 [==============================] - 11s 214ms/step - loss: 0.0730 - score_loss: 0.0160 - bbx_loss: 0.0057 - score_accuracy: 0.9929 - bbx_IoU: 0.3452 - val_loss: 0.3700 - val_score_loss: 0.2280 - val_bbx_loss: 0.0142 - val_score_accuracy: 0.9722 - val_bbx_IoU: 0.0848
#
# Epoch 00095: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00095: val_loss did not improve from 0.05361
# Epoch 96/100
# 52/52 [==============================] - 11s 214ms/step - loss: 0.0591 - score_loss: 0.0178 - bbx_loss: 0.0041 - score_accuracy: 0.9893 - bbx_IoU: 0.3219 - val_loss: 0.7849 - val_score_loss: 0.6465 - val_bbx_loss: 0.0138 - val_score_accuracy: 0.8158 - val_bbx_IoU: 0.2595
#
# Epoch 00096: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00096: val_loss did not improve from 0.05361
# Epoch 97/100
# 52/52 [==============================] - 11s 206ms/step - loss: 0.0592 - score_loss: 0.0196 - bbx_loss: 0.0040 - score_accuracy: 0.9930 - bbx_IoU: 0.2915 - val_loss: 0.3094 - val_score_loss: 0.1740 - val_bbx_loss: 0.0135 - val_score_accuracy: 0.9595 - val_bbx_IoU: 0.1885
#
# Epoch 00097: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00097: val_loss did not improve from 0.05361
# Epoch 98/100
# 52/52 [==============================] - 11s 210ms/step - loss: 0.0619 - score_loss: 0.0122 - bbx_loss: 0.0050 - score_accuracy: 0.9965 - bbx_IoU: 0.3573 - val_loss: 0.2290 - val_score_loss: 0.1575 - val_bbx_loss: 0.0072 - val_score_accuracy: 0.9324 - val_bbx_IoU: 0.2300
#
# Epoch 00098: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00098: val_loss did not improve from 0.05361
# Epoch 99/100
# 52/52 [==============================] - 12s 223ms/step - loss: 0.0595 - score_loss: 0.0161 - bbx_loss: 0.0043 - score_accuracy: 0.9930 - bbx_IoU: 0.2883 - val_loss: 0.1855 - val_score_loss: 0.1372 - val_bbx_loss: 0.0048 - val_score_accuracy: 0.9324 - val_bbx_IoU: 0.3398
#
# Epoch 00099: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00099: val_loss did not improve from 0.05361
# Epoch 100/100
# 52/52 [==============================] - 12s 238ms/step - loss: 0.0406 - score_loss: 0.0044 - bbx_loss: 0.0036 - score_accuracy: 1.0000 - bbx_IoU: 0.3160 - val_loss: 0.5029 - val_score_loss: 0.4357 - val_bbx_loss: 0.0067 - val_score_accuracy: 0.9452 - val_bbx_IoU: 0.3385
#
# Epoch 00100: val_bbx_IoU did not improve from 0.45078
#
# Epoch 00100: val_loss did not improve from 0.05361

# %%
model_logo.save(f'models/model_logo_15_{NUM_EPOCHS}.h5')

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'] )
plt.semilogy()#set_yscale('log')
# plt.loglog(basex=10,basey=2)
plt.show()

# %%
model_logo.load_weights('models/model_logo_bestLoss.h5')

# %%
model_logo.save('../models/model_logo.h5')

# %%
# определим реальную позицию прямоугольников и их координаты на изначальном изображении.
# Объединим все bounding box-ы в один.

def combined_bb(win_coords,scores, bbx, threshold=0.9):
    if np.max(scores)< threshold:
        return [-1,-1,-1,-1]
        
    top_row,left_col,bottom_row,right_col= -1,-1,-1,-1
    counter = 0
    for i, b in enumerate(bbx):
        if (scores[i] >= threshold):
            counter +=1
            box = b * win_size
            box[0] += win_coords[i][1]-box[2]/2  
            box[1] += win_coords[i][0]-box[3]/2
            box[2] += box[0]  
            box[3] += box[1]
            # if(box[1]< IM_SIZE[1]/2):
            #     continue
            if(box[1]> IM_SIZE[1]/2):
                continue
            # print(box)
            if counter==1:
                top_row = box[0] 
                left_col = box[1]
                bottom_row = box[2]
                right_col = box[3]
            else:
                if(np.abs(top_row - box[0])> win_size/2) or (np.abs(left_col - box[1])> win_size/2):
                    print(np.abs(top_row - box[0]), np.abs(left_col - box[1]) )
                    continue
                top_row = box[0] if box[0] < top_row else top_row
                left_col = box[1] if box[1] < left_col else left_col
                bottom_row = box[2] if box[2] > bottom_row else bottom_row
                right_col = box[3] if box[3] > right_col else right_col
            
            # break
    return [top_row,left_col,bottom_row-top_row,right_col-left_col]

# %%
for X_test, y_test in keras_generator(test_logo_df,batch_size=1,is_test=True):
  break

predict = model_logo.predict(X_test)

show_result(X_test,predict[0][:,0], predict[1])
# Out:
# ../pages/source_prepare/diy01a00-page02_1.tif

# %%
img = cv2.imread('../pages/source_prepare/rqv98d00-page02_1.tif')
img  = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_list = split_image(img)
predict = model_logo.predict(img_list)
show_result(img_list,predict[0][:,0],predict[1])

# Объединим кусочки в одно изображение.
bb = combined_bb(win_coords, predict[0], predict[1], threshold=0.5)
rect = patches.Rectangle((bb[0], bb[1]), bb[2], bb[3], linewidth=1, edgecolor='r', facecolor='none')

fig,ax = plt.subplots(1,1,figsize=(10,10))
ax.imshow(img, 'gray', vmin=0, vmax=1,)
ax.add_patch(rect)
plt.show()
